# %% [markdown]
# # Contents List

# %% [markdown]
# ## 01. Importing Libraries
# ## 02. Creating a Path
# ## 03. Importing Data
# ## 04. Data Wrangling
# ## 05. Data Exploration
# + 05.1 Class of Orbit - LEO
# + 05.2 Class of Orbit - MEO
# + 05.3 Class of Orbit - GEO
# ## 06. Plotting Choropleth
# + 06.1 Class of Orbit - LEO
# + 06.2 Class of Orbit - MEO
# + 06.3 Class of Orbit - GEO
# ## 07. Exporting Data
# ## 08. Observations
# ## 09. Workflow

# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm     #for color palettes
import seaborn as sns
import os
import scipy
import folium
import json

# %% [markdown]
# # 2. Creating a Paths

# %%
#Create a path
path = r'/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis'

# %%
path
# Out:
# '/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis'

# %% [markdown]
# # 03. Importing Data

# %%
#Import the cleaned Dataset
df = pd.read_csv(os.path.join(path, '02-Data', 'Prepared-Data', 'Satellite_cleaned_Ready.csv'), index_col=0)

# %%
df.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1                        UK                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#   Country of Contractor             Contractor       Users  \
# 0                   USA           Hera Systems  Commercial
# 1         Multinational        AAC Clyde Space  Commercial
# ...

# %%
#Check the Dimension
df.shape
# Out:
# (7551, 23)

# %%
#Plot the visuals to appear in the notebook
# %matplotlib inline

# %%
#Import the ".json" file for World Countries
country_geo = (os.path.join(path, '02-Data', 'Original-Data', 'world-countries.json'))

# %%
#Check the the JSON file contents
#country_geo_1 = pd.read_json(os.path.join(path, '02-Data', 'Original-Data', 'world-countries.json'))

#Open the JSON file
#with open("/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis/02-Data/Original-Data/world-countries.json", "r") as f:
 #   country_geo = json.load(f)

# %% [markdown]
# # 04. Data Wrangling

# %%
#Check the Dimension
df.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1                        UK                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#   Country of Contractor             Contractor       Users  \
# 0                   USA           Hera Systems  Commercial
# 1         Multinational        AAC Clyde Space  Commercial
# ...

# %%
#Filter the dataframe  to excludes the rows with ---Multinational values from the --Country of Operator/Owner
df_filter_1= df[df['Country of Operator/Owner'] != 'Multinational']

# %%
#Check the value
df_filter_1[df_filter_1['Country of Operator/Owner'] == 'Multinational'].shape
# Out:
# (0, 23)

# %%
#Check the dimension
df_filter_1.shape
# Out:
# (7381, 23)

# %%
#Replace values with Multinational
df_filter_1.loc[:, 'Country of Contractor'] = df_filter_1['Country of Contractor'].replace({'Denmark/Canada':'Multinational'})

# %%
#Check the value
df_filter_1[df_filter_1['Country of Contractor'] == 'Denmark/Canada'].shape
# Out:
# (0, 23)

# %%
#Filter the dataframe  to excludes the rows with ---Multinational values from the --Country of Contractor
df_filter_2= df_filter_1[df_filter_1['Country of Contractor'] != 'Multinational']

# %%
#Check the value
df_filter_2[df_filter_2['Country of Contractor'] == 'Multinational'].shape
# Out:
# (0, 23)

# %%
#Check the dimension
df_filter_2.shape
# Out:
# (7222, 23)

# %%
df_filter_2['Country of Contractor'].nunique()
# Out:
# 55

# %%
#Check for missing values
df_filter_2.isnull().sum()
# Out:
# ID Number COSPAR                   0
# Satellite Name                     0
# Country of Operator/Owner          0
# Operator/Owner                     0
# Country of Contractor              0
# Contractor                         0
# Users                              0
# Purpose                            0
# Detailed Purpose                6043
# Class of Orbit                     0
# Type of Orbit                    531
# Period (minutes)                   0
# Expected Lifetime (yrs.)           0
# Launch Mass (kg.)                  0
# Dry Mass (kg.)                  6608
# Power (watts)                   6811
# Launch Site                        0
# Launch Vehicle                     0
# Launch Year                        0
# Launch Month                       0
# Launch Mass Categories             0
# Expected Lifetime Categories       0
# Period Categories                  0
# dtype: int64

# %%
#Check the name of the Countires to match the JASON File
df_filter_2['Country of Operator/Owner'].unique()
# Out:
# array(['USA', 'Finland', 'Denmark', 'Israel', 'Austria', 'Lithuania',
#        'Norway', 'Spain', 'UAE', 'Kazakhstan', 'Algeria', 'Japan',
#        'Brazil', 'Russia', 'Angola', 'Canada', 'Argentina', 'China',
#        'Belgium', 'Turkey', 'Luxembourg', 'Switzerland', 'India',
#        'Singapore', 'Azerbaijan', 'Czech Republic', 'Germany', 'Belarus',
#        'Netherlands', 'Indonesia', 'France', 'UK', 'Australia',
#        'Bulgaria', 'South Korea', 'Tunisia', 'Taiwan', 'Italy', 'Mexico',
#        'Ecuador', 'Egypt', 'Ethiopia', 'Colombia', 'Greece', 'Malaysia',
#        'Thailand', 'Jordan', 'Iran', 'Saudi Arabia', 'Kuwait', 'Laos',
#        'South Africa', 'Vietnam', 'Slovenia', 'Nigeria', 'Pakistan',
#        'Peru', 'New Zealand', 'Chile', 'Ukraine', 'Hungary', 'Monaco',
#        'Nepal', 'Sweden', 'Sudan', 'Poland', 'Iraq', 'Bolivia', 'Estonia',
#        'Venezuela'], dtype=object)

# %%
#Replace values to match the JASON File
df_filter_2.loc[:, 'Country of Operator/Owner'] = df_filter_2['Country of Operator/Owner'].replace({'USA':'United States of America', 
                                                                                               'UK':'United Kingdom',
                                                                                              'UAE':'United Arab Emirates'})

# %%
#Check the dataframe 
df_filter_2.head(3)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
#
#   Country of Operator/Owner         Operator/Owner Country of Contractor  \
# 0  United States of America           Hera Systems                   USA
# 2                   Finland       Aalto University               Finland
# 3                   Denmark  University of Aalborg               Denmark
#
#               Contractor       Users                 Purpose  \
# 0           Hera Systems  Commercial       Earth Observation
# 2       Aalto University       Civil  Technology Development
# 3  University of Aalborg       Civil       Earth Observation
#
#                         Detailed Purpose Class of Orbit  ...  \
# 0                       Infrared Imaging            LEO  ...
# ...

# %%
#Check the values
df_filter_2['Country of Operator/Owner'].unique()
# Out:
# array(['United States of America', 'Finland', 'Denmark', 'Israel',
#        'Austria', 'Lithuania', 'Norway', 'Spain', 'United Arab Emirates',
#        'Kazakhstan', 'Algeria', 'Japan', 'Brazil', 'Russia', 'Angola',
#        'Canada', 'Argentina', 'China', 'Belgium', 'Turkey', 'Luxembourg',
#        'Switzerland', 'India', 'Singapore', 'Azerbaijan',
#        'Czech Republic', 'Germany', 'Belarus', 'Netherlands', 'Indonesia',
#        'France', 'United Kingdom', 'Australia', 'Bulgaria', 'South Korea',
#        'Tunisia', 'Taiwan', 'Italy', 'Mexico', 'Ecuador', 'Egypt',
#        'Ethiopia', 'Colombia', 'Greece', 'Malaysia', 'Thailand', 'Jordan',
#        'Iran', 'Saudi Arabia', 'Kuwait', 'Laos', 'South Africa',
#        'Vietnam', 'Slovenia', 'Nigeria', 'Pakistan', 'Peru',
#        'New Zealand', 'Chile', 'Ukraine', 'Hungary', 'Monaco', 'Nepal',
#        'Sweden', 'Sudan', 'Poland', 'Iraq', 'Bolivia', 'Estonia',
#        'Venezuela'], dtype=object)

# %%
#Check the dimensions 
df_filter_2.shape
# Out:
# (7222, 23)

# %%
#Replace values to match the JASON File
df_filter_2.loc[:, 'Country of Contractor'] = df_filter_2['Country of Contractor'].replace({'USA':'United States of America', 
                                                                                               'UK':'United Kingdom',
                                                                                              'UAE':'United Arab Emirates'})

# %%
#Replace values to match the JASON File
df_filter_2.loc[:, 'Country of Contractor'] = df_filter_2['Country of Contractor'].replace({'USA':'United States of America', 
                                                                                               'UK':'United Kingdom',
                                                                                              'UAE':'United Arab Emirates'})

# %%
#Check the dataframe 
df_filter_2.head(3)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
#
#   Country of Operator/Owner         Operator/Owner     Country of Contractor  \
# 0  United States of America           Hera Systems  United States of America
# 2                   Finland       Aalto University                   Finland
# 3                   Denmark  University of Aalborg                   Denmark
#
#               Contractor       Users                 Purpose  \
# 0           Hera Systems  Commercial       Earth Observation
# 2       Aalto University       Civil  Technology Development
# 3  University of Aalborg       Civil       Earth Observation
#
#                         Detailed Purpose Class of Orbit  ...  \
# 0                       Infrared Imaging            LEO  ...
# ...

# %%
#Check the values
df_filter_2['Country of Contractor'].unique()
# Out:
# array(['United States of America', 'Finland', 'Denmark', 'Israel',
#        'Canada', 'Kazakhstan', 'China', 'Japan', 'Brazil',
#        'United Kingdom', 'Russia', 'Argentina', 'Norway', 'Belgium',
#        'Turkey', 'France', 'Switzerland', 'India', 'Singapore',
#        'Czech Republic', 'Germany', 'Lithuania', 'Netherlands',
#        'Australia', 'South Korea', 'Tunisia', 'Italy',
#        'United Arab Emirates', 'Philippines', 'Ecuador', 'South Africa',
#        'Taiwan', 'Malaysia', 'Jordan', 'Luxembourg', 'Saudi Arabia',
#        'Kuwait', 'Indonesia', 'Spain', 'Vietnam', 'Egypt', 'Iran',
#        'Sweden', 'Uruguay', 'Mexico', 'New Zealand', 'Ukraine', 'Hungary',
#        'Monaco', 'Nepal', 'Bulgaria', 'Poland', 'Chile', 'Slovenia',
#        'Estonia'], dtype=object)

# %%
#Check the dimensions 
df_filter_2.shape
# Out:
# (7222, 23)

# %%
#Chech the Class of Orbit
df_filter_2['Class of Orbit'].unique()
# Out:
# array(['LEO', 'GEO', 'Elliptical', 'MEO'], dtype=object)

# %%
#Create a sub-dataframe the Class of Orbit --LEO
df_LEO = df_filter_2[df_filter_2['Class of Orbit'] == 'LEO']

# %%
#Chech the dataframe
df_LEO.head(5)
# Out:
#    ID Number COSPAR                                     Satellite Name  \
# 0         2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 2         2017-036L                                            Aalto-1
# 3         2016-025E                                              AAt-4
# 9         2021-022F                                   Adelis-Sampson 1
# 10        2021-022H                                   Adelis-Sampson 2
#
#    Country of Operator/Owner  \
# 0   United States of America
# 2                    Finland
# 3                    Denmark
# 9                     Israel
# 10                    Israel
#
#                                        Operator/Owner  \
# 0                                        Hera Systems
# 2                                    Aalto University
# 3                               University of Aalborg
# 9   Asher Space Research Institute at Technion/Isr...
# 10  Asher Space Research Institute at Technion/Isr...
#
# ...

# %%
#Chech the dimension
df_LEO.shape
# Out:
# (6585, 23)

# %%
#Create a sub-dataframe the Class of Orbit --MEO
df_MEO = df_filter_2[df_filter_2['Class of Orbit'] == 'MEO']

# %%
#Chech the dataframe
df_MEO.head(5)
# Out:
#     ID Number COSPAR            Satellite Name Country of Operator/Owner  \
# 171        2012-018A  Beidou 2-12 (Compass M3)                     China
# 172        2012-018B  Beidou 2-13 (Compass M4)                     China
# 173        2012-050B  Beidou 2-15 (Compass M6)                     China
# 179        2015-037A              Beidou 3M-1S                     China
# 180        2015-037B              Beidou 3M-2S                     China
#
#                            Operator/Owner Country of Contractor  \
# 171  Chinese Ministry of National Defense                 China
# 172  Chinese Ministry of National Defense                 China
# 173  Chinese Ministry of National Defense                 China
# 179  Chinese Ministry of National Defense                 China
# 180  Chinese Ministry of National Defense                 China
#
#                                             Contractor        Users  \
# 171  Space Technology Research Institute (part of C...  Multi Users
# ...

# %%
#Chech the dimension
df_MEO.shape
# Out:
# (117, 23)

# %%
#Create a sub-dataframe the Class of Orbit --GEO
df_GEO = df_filter_2[df_filter_2['Class of Orbit'] == 'GEO']

# %%
#Chech the dataframe
df_GEO.head(5)
# Out:
#    ID Number COSPAR                                 Satellite Name  \
# 13        2020-095A  Advanced Orion 10 (Mentor, NRO L-44, USA 311)
# 14        1998-029A     Advanced Orion 4 (Mentor, NROL 6, USA 139)
# 15        2003-041A    Advanced Orion 5 (Mentor, NROL 19, USA 171)
# 16        2009-001A   Advanced Orion 6 (Mentor, NRO L-26, USA 202)
# 17        2010-063A   Advanced Orion 7 (Mentor, NRO L-32, USA 223)
#
#    Country of Operator/Owner                        Operator/Owner  \
# 13  United States of America  National Reconnaissance Office (NRO)
# 14  United States of America  National Reconnaissance Office (NRO)
# 15  United States of America  National Reconnaissance Office (NRO)
# 16  United States of America  National Reconnaissance Office (NRO)
# 17  United States of America  National Reconnaissance Office (NRO)
#
#        Country of Contractor                              Contractor  \
# 13  United States of America  National Reconnaissance Laboratory (?)
# ...

# %%
#Chech the dimension
df_GEO.shape
# Out:
# (474, 23)

# %%
#Create a sub-dataframe the Class of Orbit --Elliptical
df_Elliptical = df_filter_2[df_filter_2['Class of Orbit'] == 'Elliptical']

# %%
#Chech the dataframe
df_Elliptical.head(5)
# Out:
#     ID Number COSPAR                                     Satellite Name  \
# 104        2021-016A                                         Arktika-M1
# 319        1999-040B                    Chandra X-Ray Observatory (CXO)
# 691        2015-066A  EKS-1 (Integrated Space System, Cosmos 2510, T...
# 692        2017-027A  EKS-2 (Integrated Space System, Cosmos 2518, T...
# 693        2019-065A  EKS-3 (Integrated Space System, Cosmos 2541, T...
#
#     Country of Operator/Owner  \
# 104                    Russia
# 319  United States of America
# 691                    Russia
# 692                    Russia
# 693                    Russia
#
#                                         Operator/Owner  \
# 104        Naval Physical and Oceanographic Laboratory
# 319  National Aeronautics and Space Administration ...
# 691                                Ministry of Defense
# 692                                Ministry of Defense
# 693                                Ministry of Defense
#
# ...

# %%
#Chech the dimension
df_Elliptical.shape
# Out:
# (46, 23)

# %%
#Check for missing values
df_Elliptical.isnull().sum()

#Chech the missing values for ---df_LEO ---df_MEO ---df_GEO ---df_Elliptical
# Out:
# ID Number COSPAR                 0
# Satellite Name                   0
# Country of Operator/Owner        0
# Operator/Owner                   0
# Country of Contractor            0
# Contractor                       0
# Users                            0
# Purpose                          0
# Detailed Purpose                25
# Class of Orbit                   0
# Type of Orbit                   17
# Period (minutes)                 0
# Expected Lifetime (yrs.)         0
# Launch Mass (kg.)                0
# Dry Mass (kg.)                  42
# Power (watts)                   41
# Launch Site                      0
# Launch Vehicle                   0
# Launch Year                      0
# Launch Month                     0
# Launch Mass Categories           0
# Expected Lifetime Categories     0
# Period Categories                0
# dtype: int64

# %% [markdown]
# # 05. Data Exploration

# %% [markdown]
# ## 05.1 Class of Orbit - LEO

# %%
#Check the extreme vlaues
sns.histplot(df_LEO['Launch Mass (kg.)'], bins = 20, kde = True)
plt.show()

# %%
#Check the Stat
df_LEO.describe()
# Out:
#        Period (minutes)  Expected Lifetime (yrs.)  Launch Mass (kg.)  \
# count       6585.000000               6585.000000        6585.000000
# mean          96.759171                  4.131245         295.623364
# std           30.474584                  1.042316         840.118576
# min            9.000000                  0.250000           0.500000
# 25%           94.700000                  4.000000         148.000000
# 50%           95.600000                  4.000000         260.000000
# 75%           95.900000                  4.000000         260.000000
# max         1436.100000                 25.000000       22500.000000
#
#        Launch Year  Launch Month
# count  6585.000000   6585.000000
# mean   2020.407745      5.802733
# std       3.415403      3.553205
# min    1974.000000      1.000000
# 25%    2020.000000      3.000000
# 50%    2021.000000      5.000000
# 75%    2022.000000      9.000000
# max    2023.000000     12.000000

# %%
# Check how many extreme values
df_LEO[df_LEO['Launch Mass (kg.)'] >800]
# Out:
#      ID Number COSPAR         Satellite Name Country of Operator/Owner  \
# 77          2022-131A              Angosat-2                    Angola
# 158         2015-009A   BARS-M (Cosmos 2503)                    Russia
# 159         2016-020A   BARS-M (Cosmos 2515)                    Russia
# 160         2022-054A  BARS-M3 (Cosmos 2556)                    Russia
# 161         2023-040A  BARS-M4 (Cosmos 2567)                    Russia
# ...               ...                    ...                       ...
# 7555        2011-079A           Ziyuan 1-02C                     China
# 7556        2019-059A            Ziyuan 1-2D                     China
# 7557        2012-001A        Ziyuan 3 (ZY-3)                     China
# 7558        2016-033A             Ziyuan 3-2                     China
# 7559        2020-051A             Ziyuan 3-3                     China
#
#                                          Operator/Owner Country of Contractor  \
# ...

# %%
#Clean extreme values
df_LEO_2 = df_LEO[df_LEO['Launch Mass (kg.)'] <=800]

#800kg is the threshold, this because I considered the data only up to 2 standard deviations from the mean (excluding Outliers).

# %%
#Check the dimensions 
df_LEO_2.shape
# Out:
# (6405, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_LEO_2['Launch Mass (kg.)'], bins = 20, kde = True)
plt.show()

# %%
#Check the extreme vlaues
sns.histplot(df_LEO_2['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %%
# Check how many extreme values
df_LEO_2[df_LEO_2['Expected Lifetime (yrs.)'] >15]
# Out:
#      ID Number COSPAR              Satellite Name Country of Operator/Owner  \
# 2576        2019-036C  OTB-1 (Orbital Test Bed 1)  United States of America
#
#                                        Operator/Owner Country of Contractor  \
# 2576  General Atomics - Electromagnetic Systems Group        United Kingdom
#
#                             Contractor       Users                 Purpose  \
# 2576  Surrey Satellite Technology Ltd.  Commercial  Technology Development
#
#      Detailed Purpose Class of Orbit  ... Launch Mass (kg.)  Dry Mass (kg.)  \
# 2576              NaN            LEO  ...             138.0             NaN
#
#       Power (watts)     Launch Site Launch Vehicle Launch Year Launch Month  \
# 2576            NaN  Cape Canaveral   Falcon Heavy        2019            6
#
#        Launch Mass Categories  Expected Lifetime Categories  \
# 2576  Light Weight Satellites        Long Expected Lifetime
#
#          Period Categories
# 2576  Fast Rotation Period
#
# ...

# %%
#Clean extreme values
df_LEO_2 = df_LEO_2[df_LEO_2['Expected Lifetime (yrs.)'] <=15]

#15 is the threshold, this because most of the data falls below it. --Applied changed to the same dataframe ---df_LEO_2

# %%
#Check the dimensions 
df_LEO_2.shape
# Out:
# (6404, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_LEO_2['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %% [markdown]
# ## 05.2 Class of Orbit - MEO

# %%
#Check the distribution of the vlaues
sns.histplot(df_MEO['Launch Mass (kg.)'], bins = 20, kde = True)
plt.show()

# %%
df_MEO.describe()
# Out:
#        Period (minutes)  Expected Lifetime (yrs.)  Launch Mass (kg.)  \
# count        117.000000                117.000000         117.000000
# mean         638.058974                  8.905983        1368.897436
# std          181.198009                  2.067745         672.449913
# min           97.700000                  1.000000         600.000000
# 25%          675.700000                  8.000000         800.000000
# 50%          717.920000                  9.000000        1415.000000
# 75%          767.200000                 10.000000        1630.000000
# max          787.400000                 15.000000        4352.000000
#
#        Launch Year  Launch Month
# count   117.000000    117.000000
# mean   2013.743590      7.273504
# std       5.767259      3.541926
# min    1997.000000      1.000000
# 25%    2010.000000      4.000000
# 50%    2014.000000      7.000000
# 75%    2018.000000     11.000000
# max    2023.000000     12.000000

# %%
# Check how many extreme values
df_MEO[df_MEO['Launch Mass (kg.)'] >2500]
# Out:
#      ID Number COSPAR                                     Satellite Name  \
# 173         2012-050B                           Beidou 2-15 (Compass M6)
# 1783        2023-009A  Navstar GPS III-6 (Navstar SVN 79, PRN 28, USA...
#
#      Country of Operator/Owner                        Operator/Owner  \
# 173                      China  Chinese Ministry of National Defense
# 1783  United States of America                      DoD/US Air Force
#
#          Country of Contractor  \
# 173                      China
# 1783  United States of America
#
#                                              Contractor        Users  \
# 173   Space Technology Research Institute (part of C...  Multi Users
# 1783                   Lockheed Martin Missiles & Space  Multi Users
#
#                             Purpose Detailed Purpose Class of Orbit  ...  \
# 173   Navigation/Global Positioning              NaN            MEO  ...
# 1783  Navigation/Global Positioning              NaN            MEO  ...
#
# ...

# %%
#Clean extreme values
df_MEO_2 = df_MEO[df_MEO['Launch Mass (kg.)'] <=2500]

#2500 is the threshold, because most of the data falls below it, with only two values that are significantly higher than the rest.

# %%
#Check the dimensions 
df_MEO_2.shape
# Out:
# (115, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_MEO_2['Launch Mass (kg.)'], bins = 20, kde = True)
plt.show()

# %%
#Check the distribution of the vlaues
sns.histplot(df_MEO_2['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %%
# Check how many extreme values
df_MEO_2[df_MEO_2['Expected Lifetime (yrs.)'] <6]
# Out:
#     ID Number COSPAR                               Satellite Name  \
# 667        2019-036F  DSX (Demonstration and Science Experiments)
#
#     Country of Operator/Owner                 Operator/Owner  \
# 667  United States of America  Air Force Research Laboratory
#
#         Country of Contractor                     Contractor     Users  \
# 667  United States of America  Air Force Research Laboratory  Military
#
#                     Purpose Detailed Purpose Class of Orbit  ...  \
# 667  Technology Development              NaN            MEO  ...
#
#     Launch Mass (kg.)  Dry Mass (kg.)  Power (watts)     Launch Site  \
# 667             600.0             NaN            NaN  Cape Canaveral
#
#     Launch Vehicle Launch Year Launch Month   Launch Mass Categories  \
# 667   Falcon Heavy        2019            6  Light Weight Satellites
#
#      Expected Lifetime Categories     Period Categories
# 667       Short Expected Lifetime  Fast Rotation Period
#
# [1 rows x 23 columns]

# %%
#Clean extreme values
df_MEO_2 = df_MEO_2[df_MEO_2['Expected Lifetime (yrs.)'] >=7]

#7 is the threshold, this because most of the data falls below it. --Applied changed to the same dataframe ---df_MEO_2

# %%
#Check the dimensions 
df_MEO_2.shape
# Out:
# (114, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_MEO_2['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %% [markdown]
# ## 05.3 Class of Orbit - GEO

# %%
#Check the extreem vlaues
sns.histplot(df_GEO['Launch Mass (kg.)'], bins = 20, kde = True)
plt.show()

# %%
# Check how many extreme values
df_GEO[df_GEO['Launch Mass (kg.)'] >7000]
# Out:
#      ID Number COSPAR                       Satellite Name  \
# 700         2023-016A                           Electro-L4
# 1707        1994-054A  Mercury 1 (Advanced Vortex 1,  105)
# 1708        1996-026A  Mercury 2 (Advanced Vortex 2,  118)
# 2831        2019-097A                           Shijian 20
# 7134        2018-069A       Telstar 18 VANTAGE (Apstar 5C)
# 7135        2018-059A                   Telstar 19 Vantage
#
#      Country of Operator/Owner  \
# 700                     Russia
# 1707  United States of America
# 1708  United States of America
# 2831                     China
# 7134                    Canada
# 7135                    Canada
#
#                                          Operator/Owner  \
# 700                               Roshydromet - Planeta
# 1707  National Reconnaissance Office (NRO)/US Air Force
# 1708  National Reconnaissance Office (NRO)/US Air Force
# 2831  China Aerospace Science and Technology Corpora...
# ...

# %%
df_GEO.describe()
# Out:
#        Period (minutes)  Expected Lifetime (yrs.)  Launch Mass (kg.)  \
# count        474.000000                474.000000         474.000000
# mean        1437.479304                 13.425105        4005.080169
# std          212.320057                  2.643190        1615.863334
# min           98.300000                  2.000000         100.000000
# 25%         1436.060000                 13.000000        3000.000000
# 50%         1436.100000                 15.000000        4083.000000
# 75%         1436.110000                 15.000000        5200.000000
# max         5585.000000                 20.000000        8429.000000
#
#        Launch Year  Launch Month
# count   474.000000    474.000000
# mean   2012.223629      6.930380
# std       6.972052      3.449638
# min    1988.000000      1.000000
# 25%    2008.000000      4.000000
# 50%    2013.000000      7.000000
# 75%    2017.000000     10.000000
# max    2023.000000     12.000000

# %%
#Check the dimensions 
df_GEO.shape
# Out:
# (474, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_GEO['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %%
# Check how many extreme values
df_GEO[df_GEO['Expected Lifetime (yrs.)'] <4]
# Out:
#      ID Number COSPAR      Satellite Name Country of Operator/Owner  \
# 792         2012-002A  Fengyun 2F (FY 2F)                     China
# 7070        2021-118A            STPSat-6  United States of America
#
#                            Operator/Owner     Country of Contractor  \
# 792   China Meteorological Administration                     China
# 7070                              Atlas 5  United States of America
#
#                                              Contractor       Users  \
# 792   Shanghai Academy of Spaceflight Technology (SAST)  Government
# 7070                                            Various    Military
#
#                        Purpose Detailed Purpose Class of Orbit  ...  \
# 792          Earth Observation    Earth Science            GEO  ...
# 7070  Technology Demonstration              NaN            GEO  ...
#
#      Launch Mass (kg.)  Dry Mass (kg.)  Power (watts)  \
# 792             1390.0             620            NaN
# ...

# %%
#Clean extreme values
df_GEO_2 = df_GEO[df_GEO['Expected Lifetime (yrs.)'] >=4]

#4 is the threshold, this because most of the data falls above it. --Applied changed to the same dataframe ---df_GEO_2

# %%
#Check the dimensions 
df_GEO_2.shape
# Out:
# (472, 23)

# %%
#Check the distribution of the vlaues
sns.histplot(df_GEO_2['Expected Lifetime (yrs.)'], bins = 20, kde = True)
plt.show()

# %% [markdown]
# # 06. Plotting Choropleth

# %% [markdown]
# ## 06.1 Class of Orbit - LEO

# %%
#Create a data frame with just the Launch Mass (kg) AND Country of Operator/Owner
df_toplot_LEO_mass = df_LEO_2[['Country of Operator/Owner','Launch Mass (kg.)']]

# %%
#Check the dataframe
df_toplot_LEO_mass.head()
# Out:
#    Country of Operator/Owner  Launch Mass (kg.)
# 0   United States of America               22.0
# 2                    Finland                4.5
# 3                    Denmark                1.0
# 9                     Israel                9.0
# 10                    Israel                9.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_toplot_LEO_mass_agg = df_toplot_LEO_mass.groupby('Country of Operator/Owner').agg({'Launch Mass (kg.)': 'mean'}).reset_index()

# %%
df_toplot_LEO_mass_agg.head()
# Out:
#   Country of Operator/Owner  Launch Mass (kg.)
# 0                   Algeria          56.500000
# 1                 Argentina          57.511628
# 2                 Australia          91.375000
# 3                   Austria          12.750000
# 4                   Belarus         400.000000

# %%
#Create a data frame with just the Expected Lifetime (yrs.) AND Country of Contractor
df_plot_LEO_lifetime = df_LEO_2[['Country of Contractor','Expected Lifetime (yrs.)']]

# %%
#Check the dataframe
df_plot_LEO_lifetime.head()
# Out:
#        Country of Contractor  Expected Lifetime (yrs.)
# 0   United States of America                       0.5
# 2                    Finland                       2.0
# 3                    Denmark                       4.0
# 9                     Israel                       4.0
# 10                    Israel                       4.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_plot_LEO_lifetime_agg = df_plot_LEO_lifetime.groupby('Country of Contractor').agg({'Expected Lifetime (yrs.)': 'mean'}).reset_index()

# %%
df_plot_LEO_lifetime_agg.head()
# Out:
#   Country of Contractor  Expected Lifetime (yrs.)
# 0             Argentina                  3.900000
# 1             Australia                  4.100000
# 2               Belgium                  4.000000
# 3                Brazil                  3.666667
# 4              Bulgaria                  4.000000

# %%
#Plot df_toplot_LEO_mass

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_toplot_LEO_mass_agg,
    columns = ['Country of Operator/Owner','Launch Mass (kg.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Launch Mass (kg.)").add_to(map)
folium.LayerControl().add_to(map)

display(map)

#Viridis,#Cividis,#Spectral,#Rainbow,YlOrBr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('LEO1MAP.html')

# %%
#Plot df_plot_LEO_lifetime

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_plot_LEO_lifetime_agg,
    columns = ['Country of Contractor','Expected Lifetime (yrs.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = 'Expected Lifetime (yrs.)').add_to(map)
folium.LayerControl().add_to(map)

display(map)

#Viridis,#Cividis,#Spectral,#Rainbow,YlOrBr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('LEO2MAP.html')

# %% [markdown]
# ## 06.2 Class of Orbit - MEO

# %%
#Create a data frame with just the Launch Mass (kg) AND Country of Operator/Owner
df_toplot_MEO_mass = df_MEO_2[['Country of Operator/Owner','Launch Mass (kg.)']]

# %%
#Check the dataframe
df_toplot_MEO_mass.head()
# Out:
#     Country of Operator/Owner  Launch Mass (kg.)
# 171                     China             2200.0
# 172                     China             2200.0
# 179                     China              800.0
# 180                     China              800.0
# 181                     China              800.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_toplot_MEO_mass_agg = df_toplot_MEO_mass.groupby('Country of Operator/Owner').agg({'Launch Mass (kg.)': 'mean'}).reset_index()

# %%
df_toplot_MEO_mass_agg.head()
# Out:
#   Country of Operator/Owner  Launch Mass (kg.)
# 0                     China         900.000000
# 1                    Russia        1401.258065
# 2            United Kingdom         670.000000
# 3  United States of America        1982.000000

# %%
#Create a data frame with just the Expected Lifetime (yrs.) AND Country of Contractor
df_plot_MEO_lifetime = df_MEO_2[['Country of Contractor','Expected Lifetime (yrs.)']]

# %%
#Check the dataframe
df_plot_MEO_lifetime.head()
# Out:
#     Country of Contractor  Expected Lifetime (yrs.)
# 171                 China                       8.0
# 172                 China                       8.0
# 179                 China                       8.0
# 180                 China                       8.0
# 181                 China                       8.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_plot_MEO_lifetime_agg = df_plot_MEO_lifetime.groupby('Country of Contractor').agg({'Expected Lifetime (yrs.)': 'mean'}).reset_index()

# %%
df_plot_MEO_lifetime_agg.head()
# Out:
#       Country of Contractor  Expected Lifetime (yrs.)
# 0                     China                  8.000000
# 1                    France                  9.000000
# 2                    Russia                  7.354839
# 3  United States of America                 11.028571

# %%
#Plot df_toplot_MEO_mass

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_toplot_MEO_mass_agg,
    columns = ['Country of Operator/Owner','Launch Mass (kg.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Launch Mass (kg.)").add_to(map)
folium.LayerControl().add_to(map)

display(map)

#Viridis,#Cividis,#Spectral,#Rainbow,YlOrBr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('MEO1MAP.html')

# %%
#Plot df_plot_MEO_lifetime

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_plot_MEO_lifetime_agg,
    columns = ['Country of Contractor','Expected Lifetime (yrs.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = 'Expected Lifetime (yrs.)').add_to(map)
folium.LayerControl().add_to(map)

display(map)

#Viridis,#Cividis,#Spectral,#Rainbow,YlOrBr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('MEO2MAP.html')

# %% [markdown]
# ## 06.3 Class of Orbit - GEO

# %%
#Create a data frame with just the Launch Mass (kg) AND Country of Operator/Owner
df_toplot_GEO_mass = df_GEO_2[['Country of Operator/Owner','Launch Mass (kg.)']]

# %%
#Check the dataframe
df_toplot_GEO_mass.head()
# Out:
#    Country of Operator/Owner  Launch Mass (kg.)
# 13  United States of America             5400.0
# 14  United States of America             5200.0
# 15  United States of America             5200.0
# 16  United States of America             5400.0
# 17  United States of America             5000.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_toplot_GEO_mass_agg = df_toplot_GEO_mass.groupby('Country of Operator/Owner').agg({'Launch Mass (kg.)': 'mean'}).reset_index()

# %%
df_toplot_GEO_mass_agg.head()
# Out:
#   Country of Operator/Owner  Launch Mass (kg.)
# 0                   Algeria        5225.000000
# 1                 Argentina        2988.500000
# 2                 Australia        4016.571429
# 3                Azerbaijan        3375.000000
# 4                   Bolivia        5000.000000

# %%
#Create a data frame with just the Expected Lifetime (yrs.) AND Country of Contractor
df_plot_GEO_lifetime = df_GEO_2[['Country of Contractor','Expected Lifetime (yrs.)']]

# %%
#Check the dataframe
df_plot_GEO_lifetime.head()
# Out:
#        Country of Contractor  Expected Lifetime (yrs.)
# 13  United States of America                      13.0
# 14  United States of America                      13.0
# 15  United States of America                      13.0
# 16  United States of America                      13.0
# 17  United States of America                      13.0

# %%
#Aaggregate the data based on the sum of --Launch Mass (kg.) so that each country only appears once in the dataframe. 
df_plot_GEO_lifetime_agg = df_plot_GEO_lifetime.groupby('Country of Contractor').agg({'Expected Lifetime (yrs.)': 'mean'}).reset_index()

# %%
df_plot_GEO_lifetime_agg.head()
# Out:
#   Country of Contractor  Expected Lifetime (yrs.)
# 0             Argentina                 15.000000
# 1                 China                 12.153846
# 2                France                 14.520000
# 3               Germany                 15.000000
# 4                 India                 12.241379

# %%
#Plot df_toplot_GEO_mass

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_toplot_GEO_mass_agg,
    columns = ['Country of Operator/Owner','Launch Mass (kg.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "Launch Mass (kg.)").add_to(map)
folium.LayerControl().add_to(map)

display(map)

#Viridis,#Cividis,#Spectral,#Rainbow,YlOrBr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('GEO1MAP.html')

# %%
#Plot df_plot_GEO_lifetime

# Setup a folium map at a high-level zoom
map = folium.Map(location = [20, 0], zoom_start = 2) # Adjusted initial location for better visibility

# Choropleth maps bind Pandas Data Frames and json geometries.This allows us to quickly visualize data combinations
folium.Choropleth(
    geo_data = country_geo, 
    data = df_plot_GEO_lifetime_agg,
    columns = ['Country of Contractor','Expected Lifetime (yrs.)'],
    key_on = 'feature.properties.name', # this part is very important - check your json file to see where the KEY is located
    fill_color = 'Spectral', fill_opacity=0.6, line_opacity=0.1,
    legend_name = 'Expected Lifetime (yrs.)').add_to(map)
folium.LayerControl().add_to(map)

display(map)


#Viridis
#Cividis
#Spectral
#Rainbow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#To Save in HTML
map.save('GEO2MAP.html')

# %% [markdown]
# # 07. Exporting Data

# %%
#Exporting the cleaned -df_filter_2 to Prepared-Data
df_filter_2.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'df_clean_updated.csv'))

# %%
#Exporting the cleaned -df_LEO_2 to Prepared-Data
df_LEO_2.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'df_LEO.csv'))

# %%
#Exporting the cleaned -df_MEO_2 to Prepared-Data
df_MEO_2.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'df_MEO.csv'))

# %%
#Exporting the cleaned -df_GEO_2 to Prepared-Data
df_GEO_2.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'df_GEO.csv'))

# %% [markdown]
# # 08. Observations

# %% [markdown]
# ## Class of Orbit - LEO
# ### Country of Operator/Owner & Launch Mass (kg):
# + On average, the United States, Russia, and Egypt have medium-weight Low Earth Orbit (LEO) satellites orbiting the Earth, with weights between 215 kg and 287 kg.
# + Meanwhile, India and Iran have heavy-weight LEO satellites orbiting the Earth, with weights between 287 kg and 358 kg, on average.
# + Peru has the heaviest LEO satellites orbiting the Earth, with weights greater than 358 kg, on average.
#
# ### Country of Contractor & Expected Lifetime (yrs):
# + Most countries build LEO satellites with a short lifetime of between 3 and 5 years, on average.
# + Meanwhile, Russia, the United Kingdom, and Poland build LEO satellites with a medium lifetime of between 5 and 7 years, on average.
# + Italy builds satellites with a long lifetime of between 10 and 12 years, on average.
#
#
# ## Class of Orbit - MEO
# ### Country of Operator/Owner & Launch Mass (kg):
# + Only four countries have Medium Earth Orbit (MEO) satellites: the United States, Russia, the United Kingdom, and China.
# + The United States is the only country with heavy MEO satellites orbiting the Earth, with an average weight of 1,763 kg.
# + This is followed by Russia, with lighter MEO satellites orbiting the Earth, weighing between 1,326 kg and 1,545 kg on average.
# + China and the United Kingdom have lighter MEO satellites orbiting the Earth with an average weight lower than 1,107 kg.
# ### Country of Contractor & Expected Lifetime (yrs):
# + Only four countries build Medium Earth Orbit (MEO) satellites: the United States, Russia, the United Kingdom, and China.
# + The United States builds MEO satellites with a long lifetime, averaging more than 10.4 years.
# + On the other hand, Russia, the United Kingdom, and China build MEO satellites with a shorter lifetime, averaging less than 9.2 years.
#
#
# ## Class of Orbit - GEO
# ### Country of Operator/Owner & Launch Mass (kg):
# + Greece, Canada, and Algeria are countries with heavy GEO satellites orbiting the Earth, with an average weight of 5,826 kg.
# + The rest of the countries have GEO satellites orbiting the Earth with medium to low weights on average.
# ### Country of Contractor & Expected Lifetime (yrs):
# + There are few countries that build GEO satellites.
# + France,the United Kingdom, Argentina, and Poland are the countries that build GEO satellites with long lifetimes, averaging more than 14.2 years.
# + The rest of the countries build GEO satellites with medium to short lifetimes, averaging less than 14.2 years.

# %% [markdown]
# # 09. Workflow

# %% [markdown]
# ### The dataframe (df) contains 7551 rows and 23 columns.
# + Since I plan to plot a map, I need to filter out 'Multinational' values from both the "Country of Operator/Owner" and "Country of Contractor" columns.
# + There are 83 instances where "Multinational" is found in both columns simultaneously.
# + Additionally, there are 326 instances where "Multinational" is found in either column.
#
# + I filtered out "Multinational" from the "Country of Operator/Owner" column, resulting in 170 rows being removed.
# + The "Country of Operator/Owner" column now has 73 unique values.
# + After dropping the rows containing "Multinational," the dataframe (df_filter_1) contains 7381 rows and 23 columns.
#
# + I filtered out "Multinational" from the "Country of Contractor" column, resulting in 159 rows being removed.
# + The "Country of Contractor" column now has 55 unique values.
# + I found values incorrectly labeled, specifically "Denmark/Canada." There are 3 rows with "Denmark/Canada," which I replaced with "Multinational."
# + After this change, I dropped the rows containing "Multinational."
#
# ### Now, the dataframe (df_filter_2) contains 7222 rows and 23 columns.
#
# ## I checked the names of the countries to match the JSON file for both "Country of Operator/Owner" and "Country of Contractor":
# + USA should be updated to "United States of America"
# + UK should be updated to "United Kingdom"
# + UAE should be updated to "United Arab Emirates"
# + Please note that Monaco and Singapore are not represented on the map.
#
# ### Now, the dataframe (df_filter_2) contains 7,222 rows and 23 columns.
#
# # The class of orbit is a confounding factor in the data. Therefore, I decided to control for this by creating separate dataframes for each class of orbit. This approach allows for a more precise analysis and addresses the questions at hand more effectively.
# ### I created the following dataframes based on the class of orbit:
# + For Class of Orbit = LEO, the dataframe (df_LEO) contains 6585 rows and 23 columns.
# + For Class of Orbit = MEO, the dataframe (df_MEO) contains 117 rows and 23 columns.
# + For Class of Orbit = GEO, the dataframe (df_GEO) contains 474 rows and 23 columns.
# + For Class of Orbit = Elliptical, the dataframe (df_Elliptical) contains 46 rows and 23 columns.
#
# ### Now, I can work with the data based on the class of orbit.
#
# ## I checked for missing values in the dataframes: `df_LEO`, `df_MEO`, `df_GEO`, and `df_Elliptical`. There are missing values in variables that I am not interested in (Detailed Purpose, Dry Mass (kg), Power (watts), and Type of Orbit). Therefore, I decided not to address those missing values.
# + I decided to focus on the three main classes of orbits: LEO, MEO, and GEO.
#
# ## For `df_LEO_2`, I applied the following filters:
# ### Launch Mass (kg):
# + I included values up to 800 kg. This threshold was chosen because it includes data within 2 standard deviations from the mean. There are 180 extreme values, resulting in a dataframe (`df_LEO_2`) with 6405 rows and 23 columns.
# ### Expected Lifetime (yrs.):
# + I set a threshold of up to 15 years, as most of the data falls below this value. There is one extreme value, resulting in a dataframe (`df_LEO_2`) with 6404 rows and 23 columns.
#
# ## For `df_MEO_2`, I applied the following filters:
# ### Launch Mass (kg):
# + I included values up to 2,500 kg. This threshold was chosen because most of the data falls below this value, with only two outliers that are significantly higher.
# + After removing these extreme values, the dataframe (`df_MEO_2`) contains 115 rows and 23 columns.
# ### Expected Lifetime (yrs.):
# + I set a threshold of greater than 7 years, as most of the data falls above this value.
# + After removing 1 extreme value, the dataframe (`df_MEO_2`) contains 114 rows and 23 columns.
#
# ## For `df_GEO_2`, I applied the following considerations:
# ### Launch Mass (kg):
# + There is no need to filter the data, as the distribution of values is within a reasonable range. Therefore, there are no extreme values, and the dataframe (`df_GEO_2`) contains 474 rows and 23 columns.
# ### Expected Lifetime (yrs.):
# + I set a threshold of greater than 4 years, as most of the data falls above this value.
# + After removing 2 extreme values, the dataframe (`df_GEO_2`) contains 472 rows and 23 columns.
#
# ### I created a data frame for each class where each data frame contains the columns I want to plot.
# ### I am plotting 4 different columns for each class, that is in two data frames, for each Class of  Orbit.
#
# ## Plotting Choropleth Map
# ### For the classes LEO, MEO, and GEO, I explored two primary questions:
# 1. Who has the heaviest satellites orbiting the Earth, on average?
# - Analyzed using Launch Mass (kg) vs. Country of Operator/Owner.
# 2. Who manufactures satellites with the longest expected lifetime, on average?
# - Analyzed using Expected Lifetime (yrs.) vs. Country of Contractor.
#
# + To address these questions, I created a separate dataframe for each class of orbit (LEO, MEO, GEO), containing the specific columns I wanted to plot. For each class, I plotted data on two maps, focusing on:
# - Country of Operator/Owner vs. Launch Mass (kg)
# - Country of Contractor vs. Expected Lifetime (yrs.)
# + This approach allowed for a visual representation of how different countries are leading in satellite mass and expected lifetime (on average) within each orbit class.
