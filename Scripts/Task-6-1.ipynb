# %% [markdown]
# # Contents List
#
# + 01. Importing Libraries
# + 02. Importing Data
# + 03. Creating a Path
# + 04. Data Profile
# + 05. Data Cleaning
#       + Drop Columns
#       + Rename Columns
#       + Reorder Columns
#       + Leading and Trailing White Space Checks
#       + Data Types
#       + Inconsistency Checks
#       + Duplicates
#       + Missing values
#       + Time Variable
# + 06. Summary Statistics
# + 07. Exporting Data
# + 08. Workflow

# %% [markdown]
# # 01. Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
df = pd.read_excel(r'/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis/02-Data/Original-Data/UCS-Satellite-Database.xlsx', index_col = False)

# %%
df
# Out:
#                      Name of Satellite, Alternate Names  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                               AAC AIS-Sat1 (Kelpie 1)
# 2                                              Aalto-1
# 3                                                 AAt-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 7555                                       Ziyuan 1-02C
# 7556                                        Ziyuan 1-2D
# 7557                                    Ziyuan 3 (ZY-3)
# 7558                                         Ziyuan 3-2
# 7559                                         Ziyuan 3-3
#
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                            1HOPSAT-TD                         NR
# 1               AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                               Aalto-1                    Finland
# ...

# %% [markdown]
# # 03. Creating a Path

# %%
#Create a path varaible - Shortcut for Importing Data Files
path = r'/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis'

# %%
path
# Out:
# '/Users/aya/Desktop/DataAnalytics/Data-Immersion/Achievement-6/UCS-Satellite-Analysis'

# %%
#Join paths
df = pd.read_excel(os.path.join(path, '02-Data', 'Original-Data', 'UCS-Satellite-Database.xlsx'), index_col = False)

# %%
df.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1            AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                            Aalto-1                    Finland
# 3                              AAt-4                    Denmark
# 4                              ABS-2                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# ...

# %% [markdown]
# # 04. Data Profile

# %%
#Check the list of columns
df.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', 'Dry Mass (kg.)', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments', 'Unnamed: 28',
#        'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
#        'Source.3', 'Source.4', 'Source.5', 'Source.6', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
# ...

# %%
#Check the variables Counts
df['Launch Mass (kg.)'].count()

#The checked variables: -- 
#'COSPAR Number', 'Country of Operator/Owner','Operator/Owner','Users','Purpose',
#'Class of Orbit','Type of Orbit','Longitude of GEO (degrees)','Period (minutes)','Expected Lifetime (yrs.)',
#'Date of Launch','Launch Mass (kg.)','Contractor','Country of Contractor','Launch Site','Launch Vehicle'
# Out:
# 7315

# %%
#Check the variables Unique Values
df['Launch Mass (kg.)'].nunique()

#The checked variables: -- 
#'COSPAR Number','Country of Operator/Owner', 'Operator/Owner','Users','Purpose',
##'Class of Orbit','Type of Orbit','Longitude of GEO (degrees)','Period (minutes)', 'Expected Lifetime (yrs.)',
#'Date of Launch','Launch Mass (kg.)','Contractor','Country of Contractor','Launch Vehicle'
# Out:
# 595

# %%
#Check the variables Mean, Median,Minimum, Maximumm  Values
df['Launch Mass (kg.)'].agg(['mean', 'median', 'min', 'max'])

#The checked variables: -- 
#'Longitude of GEO (degrees)','Period (minutes)', 'Expected Lifetime (yrs.)',
# Out:
# mean        626.321319
# median      260.000000
# min           0.500000
# max       22500.000000
# Name: Launch Mass (kg.), dtype: float64

# %%
#Check the variables Mode Values
df['Launch Mass (kg.)'].mode()

#The checked variables: -- 
#'Country of Operator/Owner', 'Operator/Owner','Users','Class of Orbit','Type of Orbit',
#'Date of Launch', 'Contractor','Country of Contractor','Launch Site','Launch Vehicle'
# Out:
# 0    260.0
# Name: Launch Mass (kg.), dtype: float64

# %% [markdown]
# # 05. Data Cleaning

# %%
#Check the dimensions 
df.shape
# Out:
# (7560, 68)

# %%
#Check the variables - columns in the dataframe
df.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', 'Dry Mass (kg.)', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments', 'Unnamed: 28',
#        'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
#        'Source.3', 'Source.4', 'Source.5', 'Source.6', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
# ...

# %%
#Print the Stats
df.describe()
# Out:
#        Longitude of GEO (degrees)  Perigee (km)    Apogee (km)  Eccentricity  \
# count                 7557.000000   7553.000000    7553.000000   7549.000000
# mean                     1.704567   3703.945187    4236.369390      0.480882
# min                   -179.800000    150.000000      49.000000     -0.033429
# 25%                      0.000000    521.000000     536.000000      0.000199
# 50%                      0.000000    548.000000     561.000000      0.000297
# 75%                      0.000000    600.000000     626.000000      0.000939
# max                    359.000000  62200.000000  353798.000000    575.000000
# std                     26.292065   9715.789212   13123.003517     15.567178
#
#        Inclination (degrees)  Period (minutes)  Launch Mass (kg.)  \
# count            7556.000000       7504.000000        7315.000000
# mean               62.534161        224.016189         626.321319
# min                 0.000000          9.000000           0.500000
# ...

# %%
#Check the Columns Data Types
df.dtypes
# Out:
# Name of Satellite, Alternate Names    object
# Current Official Name of Satellite    object
# Country/Org of UN Registry            object
# Country of Operator/Owner             object
# Operator/Owner                        object
#                                        ...
# Unnamed: 63                           object
# Unnamed: 64                           object
# Unnamed: 65                           object
# Unnamed: 66                           object
# Unnamed: 67                           object
# Length: 68, dtype: object

# %%
#Exapnd the current output 
pd.options.display.max_rows = None

# %%
#Create a dataframe to filter out columns with 'Source' and 'Unnamed'
columns_to_drop = [col for col in df.columns if 'Source' in col or 'Unnamed' in col]

# %%
#Check the dataframe
columns_to_drop
# Out:
# ['Unnamed: 28',
#  'Source Used for Orbital Data',
#  'Source',
#  'Source.1',
#  'Source.2',
#  'Source.3',
#  'Source.4',
#  'Source.5',
#  'Source.6',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
#  'Unnamed: 58',
#  'Unnamed: 59',
#  'Unnamed: 60',
#  'Unnamed: 61',
#  'Unnamed: 62',
#  'Unnamed: 63',
#  'Unnamed: 64',
#  'Unnamed: 65',
#  'Unnamed: 66',
#  'Unnamed: 67']

# %%
#Dropp the 'Source' and 'Unnamed' columns from the dataframe -df and assigning it to a new dataframe named -df_dropped
df_dropped = df.drop(columns=columns_to_drop)

# %%
#Check the dimensions
df_dropped.shape
# Out:
# (7560, 28)

# %%
#Checking the dataframe
df_dropped.head(5)
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1            AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                            Aalto-1                    Finland
# 3                              AAt-4                    Denmark
# 4                              ABS-2                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# ...

# %%
#Check the variables - columns in the dataframe
df_dropped.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', 'Dry Mass (kg.)', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments'],
#       dtype='object')

# %%
#Create another dataframe to filter out more list of columns - based on the questions to investigate
#A list of columns to drop
columns_to_drop_2 = ['Current Official Name of Satellite', 'Country/Org of UN Registry',
                     'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
                     'Eccentricity', 'Inclination (degrees)','NORAD Number', 'Comments']

# %%
#Check the columns list
columns_to_drop_2
# Out:
# ['Current Official Name of Satellite',
#  'Country/Org of UN Registry',
#  'Longitude of GEO (degrees)',
#  'Perigee (km)',
#  'Apogee (km)',
#  'Eccentricity',
#  'Inclination (degrees)',
#  'NORAD Number',
#  'Comments']

# %%
#Drop the list of columns from the dataframe --df_dropped-- and assigning it to a new dataframe named --df_dropped_2--
df_dropped_2 = df_dropped.drop(columns=columns_to_drop_2)

# %%
df_dropped_2.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# 2                   Finland               Aalto University       Civil
# 3                   Denmark          University of Aalborg       Civil
# 4             Multinational  Asia Broadcast Satellite Ltd.  Commercial
#
#                   Purpose                       Detailed Purpose  \
# 0       Earth Observation                       Infrared Imaging
# 1       Earth Observation  Automatic Identification System (AIS)
# ...

# %%
#Check the dimensions
df_dropped_2.shape
# Out:
# (7560, 19)

# %%
#Rename columns
df_dropped_2.rename(columns={'Name of Satellite, Alternate Names': 'Satellite Name', 'COSPAR Number': 'ID Number COSPAR'}, inplace=True)

# %%
df_dropped_2.head(5)
# Out:
#                                       Satellite Name  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# 2                   Finland               Aalto University       Civil
# 3                   Denmark          University of Aalborg       Civil
# 4             Multinational  Asia Broadcast Satellite Ltd.  Commercial
#
#                   Purpose                       Detailed Purpose  \
# 0       Earth Observation                       Infrared Imaging
# 1       Earth Observation  Automatic Identification System (AIS)
# ...

# %%
#Reorder the columns and assigned it to a new dataframe
df_dropped_2_reorder = df_dropped_2.iloc[:, [18, 0, 1, 2, 15, 14, 3, 4, 5, 6,
                                             7, 8, 13, 12, 9, 10, 11, 16, 17]]

# %%
#Check the dataframe
df_dropped_2_reorder.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                           Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1            United Kingdom                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#        Country of Contractor             Contractor       Users  \
# 0                        USA           Hera Systems  Commercial
# ...

# %%
#Check the dataframe
df_dropped_2_reorder.shape
# Out:
# (7560, 19)

# %%
#Check the datatype
df_dropped_2_reorder.dtypes
# Out:
# ID Number COSPAR                     object
# Satellite Name                       object
# Country of Operator/Owner            object
# Operator/Owner                       object
# Country of Contractor                object
# Contractor                           object
# Users                                object
# Purpose                              object
# Detailed Purpose                     object
# Class of Orbit                       object
# Type of Orbit                        object
# Period (minutes)                    float64
# Expected Lifetime (yrs.)            float64
# Date of Launch               datetime64[ns]
# Launch Mass (kg.)                   float64
# Dry Mass (kg.)                       object
# Power (watts)                        object
# Launch Site                          object
# Launch Vehicle                       object
# dtype: object

# %%
#Remove White Spaces
#Convert all the data to a string data type, and apply remove the White Spaces, assign it to a new dataframe
df_datatype = df_dropped_2_reorder.map(lambda x: str(x).strip())

# %%
#Check the dataframe
df_datatype.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1            United Kingdom                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#        Country of Contractor             Contractor       Users  \
# 0                        USA           Hera Systems  Commercial
# ...

# %%
#Check the datatype
df_datatype.dtypes
# Out:
# ID Number COSPAR             object
# Satellite Name               object
# Country of Operator/Owner    object
# Operator/Owner               object
# Country of Contractor        object
# Contractor                   object
# Users                        object
# Purpose                      object
# Detailed Purpose             object
# Class of Orbit               object
# Type of Orbit                object
# Period (minutes)             object
# Expected Lifetime (yrs.)     object
# Date of Launch               object
# Launch Mass (kg.)            object
# Dry Mass (kg.)               object
# Power (watts)                object
# Launch Site                  object
# Launch Vehicle               object
# dtype: object

# %%
#Revert all the non-string data types to float data type, update the same dataframe
df_datatype[['Period (minutes)', 'Expected Lifetime (yrs.)','Launch Mass (kg.)']] = df_datatype[['Period (minutes)', 'Expected Lifetime (yrs.)','Launch Mass (kg.)']].astype(float)

# %%
#Check the dataframe
df_datatype.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1            United Kingdom                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#        Country of Contractor             Contractor       Users  \
# 0                        USA           Hera Systems  Commercial
# ...

# %%
#Check the datatype
df_datatype.dtypes
# Out:
# ID Number COSPAR              object
# Satellite Name                object
# Country of Operator/Owner     object
# Operator/Owner                object
# Country of Contractor         object
# Contractor                    object
# Users                         object
# Purpose                       object
# Detailed Purpose              object
# Class of Orbit                object
# Type of Orbit                 object
# Period (minutes)             float64
# Expected Lifetime (yrs.)     float64
# Date of Launch                object
# Launch Mass (kg.)            float64
# Dry Mass (kg.)                object
# Power (watts)                 object
# Launch Site                   object
# Launch Vehicle                object
# dtype: object

# %%
#Create a fuction to search for a mixed datatype in columns
for col in df_datatype.columns.tolist():
    weird = (df_datatype[[col]].map(type) != df_datatype[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_datatype[weird]) > 0:
        print (col)

# %%
#Check the dimensions 
df_datatype.shape
# Out:
# (7560, 19)

# %%
#Assign/copy df_datatype to a new df_datatype
df_dropped_3 = df_datatype.copy()

# %%
#Check the dataframe 
df_dropped_3.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1            United Kingdom                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#        Country of Contractor             Contractor       Users  \
# 0                        USA           Hera Systems  Commercial
# ...

# %%
#Check the dimensions 
df_dropped_3.shape
# Out:
# (7560, 19)

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['ID Number COSPAR'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['ID Number COSPAR'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['ID Number COSPAR'].nunique()
# Out:
# 7551

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Satellite Name'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Satellite Name'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Satellite Name'].nunique()
# Out:
# 7537

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Country of Operator/Owner'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Country of Operator/Owner'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Operator/Owner'].nunique()
# Out:
# 104

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Operator/Owner'].value_counts().sort_index()
# Out:
# Country of Operator/Owner
# Algeria                                 5
# Angola                                  1
# Argentina                              47
# Australia                              23
# Austria                                 2
# Azerbaijan                              2
# Bangladesh                              1
# Belarus                                 2
# Belgium                                 2
# Bolivia                                 1
# Brazil                                 15
# Bulgaria                                2
# Canada                                 60
# Chile                                   4
# China                                 618
# China/Brazil                            2
# China/France                            2
# China/Italy                             1
# Colombia                                2
# Czech Republic                          4
# Denmark                                 6
# ESA                                    63
# ...

# %%
#Create a list of --Multinational-- from --Country of Operator/Owner--
multinational_countries = ['China/Brazil','China/France','China/Italy','France/Israel','France/Italy',
                            'France/Italy/Belgium/Spain/Greece','Greece/United Kingdom','India/Canada',
                            'India/France','Japan/Singapore','Morocco/Germany','Poland/UK','Singapore/Taiwan',
                            'Turkmenistan/Monaco','USA/Argentina','USA/Canada','USA/Canada/Japan','USA/France',
                            'USA/Germany','USA/India/Singapore/Taiwan','USA/Japan','USA/Japan/Brazil','France/Belgium/Sweden',
                           'USA/Poland','USA/United Kingdom/Italy','United Kingdom/Netherlands','ESA', 'ESA/Russia','United Kingdom/ESA']

# %%
#Check the list
multinational_countries
# Out:
# ['China/Brazil',
#  'China/France',
#  'China/Italy',
#  'France/Israel',
#  'France/Italy',
#  'France/Italy/Belgium/Spain/Greece',
#  'Greece/United Kingdom',
#  'India/Canada',
#  'India/France',
#  'Japan/Singapore',
#  'Morocco/Germany',
#  'Poland/UK',
#  'Singapore/Taiwan',
#  'Turkmenistan/Monaco',
#  'USA/Argentina',
#  'USA/Canada',
#  'USA/Canada/Japan',
#  'USA/France',
#  'USA/Germany',
#  'USA/India/Singapore/Taiwan',
#  'USA/Japan',
#  'USA/Japan/Brazil',
#  'France/Belgium/Sweden',
#  'USA/Poland',
#  'USA/United Kingdom/Italy',
#  'United Kingdom/Netherlands',
#  'ESA',
#  'ESA/Russia',
#  'United Kingdom/ESA']

# %%
#Replace the list with --Multinational-- and update the dataframe 
df_dropped_3['Country of Operator/Owner'] = df_dropped_3['Country of Operator/Owner'].replace(multinational_countries ,'Multinational')

# %%
#Check the data frame
df_dropped_3['Country of Operator/Owner'].unique()
# Out:
# array(['USA', 'United Kingdom', 'Finland', 'Denmark', 'Multinational',
#        'Israel', 'Austria', 'Lithuania', 'Norway', 'Spain',
#        'United Arab Emirates', 'Kazakhstan', 'Algeria', 'Japan', 'Brazil',
#        'Russia', 'South Korea', 'Angola', 'Canada', 'Argentina', 'China',
#        'Belgium', 'Turkey', 'Luxembourg', 'Switzerland', 'India',
#        'Singapore', 'Azerbaijan', 'Bangladesh', 'Czech Republic',
#        'Germany', 'Belarus', 'Netherlands', 'Indonesia', 'France',
#        'Australia', 'Bulgaria', 'Tunisia', 'Taiwan', 'Italy', 'Mexico',
#        'Ecuador', 'Egypt', 'Ethiopia', 'Colombia', 'Greece', 'Malaysia',
#        'Thailand', 'Jordan', 'Iran', 'Saudi Arabia', 'Kuwait', 'Laos',
#        'South Africa', 'Vietnam', 'Morocco', 'Slovenia', 'Sinapore',
#        'Nigeria', 'Sweden', 'Pakistan', 'Peru', 'New Zealand', 'Chile',
#        'Ukraine', 'Hungary', 'Monaco', 'Nepal', 'Sudan', 'Poland',
# ...

# %%
#Replace the other inconsistencies in the column  
df_dropped_3['Country of Operator/Owner'] = df_dropped_3['Country of Operator/Owner'].replace({'China ': 'China', 
                                                                                               'Sinapore': 'Singapore',
                                                                                              'United Arab Emirates':'UAE',
                                                                                              'United Kingdom':'UK'})

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Operator/Owner'].value_counts().sort_index()
# Out:
# Country of Operator/Owner
# Algeria              5
# Angola               1
# Argentina           47
# Australia           23
# Austria              2
# Azerbaijan           2
# Bangladesh           1
# Belarus              2
# Belgium              2
# Bolivia              1
# Brazil              15
# Bulgaria             2
# Canada              60
# Chile                4
# China              618
# Colombia             2
# Czech Republic       4
# Denmark              6
# Ecuador              1
# Egypt                7
# Estonia              1
# Ethiopia             2
# Finland             25
# France              33
# Germany             47
# Greece               2
# Hungary              2
# India               59
# Indonesia            7
# Iran                 2
# Iraq                 1
# Israel              29
# Italy               15
# Japan               87
# Jordan               1
# Kazakhstan           6
# Kenya                1
# Kuwait               2
# ...

# %%
#Check the data frame
df_dropped_3['Country of Operator/Owner'].unique()
# Out:
# array(['USA', 'UK', 'Finland', 'Denmark', 'Multinational', 'Israel',
#        'Austria', 'Lithuania', 'Norway', 'Spain', 'UAE', 'Kazakhstan',
#        'Algeria', 'Japan', 'Brazil', 'Russia', 'South Korea', 'Angola',
#        'Canada', 'Argentina', 'China', 'Belgium', 'Turkey', 'Luxembourg',
#        'Switzerland', 'India', 'Singapore', 'Azerbaijan', 'Bangladesh',
#        'Czech Republic', 'Germany', 'Belarus', 'Netherlands', 'Indonesia',
#        'France', 'Australia', 'Bulgaria', 'Tunisia', 'Taiwan', 'Italy',
#        'Mexico', 'Ecuador', 'Egypt', 'Ethiopia', 'Colombia', 'Greece',
#        'Malaysia', 'Thailand', 'Jordan', 'Iran', 'Saudi Arabia', 'Kuwait',
#        'Laos', 'South Africa', 'Vietnam', 'Morocco', 'Slovenia',
#        'Nigeria', 'Sweden', 'Pakistan', 'Peru', 'New Zealand', 'Chile',
#        'Ukraine', 'Hungary', 'Monaco', 'Nepal', 'Sudan', 'Poland',
#        'Kenya', 'Iraq', 'Bolivia', 'Estonia', 'Venezuela'], dtype=object)

# %%
#Check the data frame
df_dropped_3['Country of Operator/Owner'].nunique()
# Out:
# 74

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Operator/Owner'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Operator/Owner'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Operator/Owner'].nunique()
# Out:
# 665

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Users'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Users'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Users'].nunique()
# Out:
# 17

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Users'].unique()
# Out:
# array(['Commercial', 'Civil', 'Government', 'Military',
#        'Military/Commercial', 'Government/Military',
#        'Military/Government', 'Government/Civil', 'Military/Civil',
#        'Commercial/Civil', 'Civil/Commercial', 'Government/Commercial',
#        'Commercial/Government', 'Government/Commercial/Military',
#        'Civil/Government', 'Civil/Military', 'Commercial/Military'],
#       dtype=object)

# %%
#Replace the inconsistencies in the column  
df_dropped_3['Users'] = df_dropped_2['Users'].replace({'Commercial ': 'Commercial', 
                                                      'Government ': 'Government',
                                                      'Military ':'Military'})

# %%
#Check the columns 
df_dropped_3['Users'].unique()
# Out:
# array(['Commercial', 'Civil', 'Government', 'Military',
#        'Military/Commercial', 'Government/Military',
#        'Military/Government', 'Government/Civil', 'Military/Civil',
#        'Commercial/Civil', 'Civil/Commercial', 'Government/Commercial',
#        'Commercial/Government', 'Government/Commercial/Military',
#        'Civil/Government', 'Civil/Military', 'Commercial/Military'],
#       dtype=object)

# %%
#Create a list of --Multi Users-- from --Users--
Multi_Users = ['Military/Commercial','Military/Government','Military/Civil',
               'Government/Military','Government/Civil','Government/Commercial',
               'Commercial/Government','Commercial/Military','Commercial/Civil',
               'Civil/Commercial','Civil/Government', 'Civil/Military','Government/Commercial/Military']

# %%
#Check the list
Multi_Users
# Out:
# ['Military/Commercial',
#  'Military/Government',
#  'Military/Civil',
#  'Government/Military',
#  'Government/Civil',
#  'Government/Commercial',
#  'Commercial/Government',
#  'Commercial/Military',
#  'Commercial/Civil',
#  'Civil/Commercial',
#  'Civil/Government',
#  'Civil/Military',
#  'Government/Commercial/Military']

# %%
#Replace the list with --Multi Users-- and update the dataframe 
df_dropped_3['Users'] = df_dropped_3['Users'].replace(Multi_Users ,'Multi Users')

# %%
#Check the dataframe
df_dropped_3['Users'].unique()
# Out:
# array(['Commercial', 'Civil', 'Government', 'Military', 'Multi Users'],
#       dtype=object)

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Users'].nunique()
# Out:
# 5

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Users'].value_counts().sort_index()
# Out:
# Users
# Civil           160
# Commercial     6081
# Government      559
# Military        458
# Multi Users     302
# Name: count, dtype: int64

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Purpose'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_2['Purpose'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Purpose'].nunique()
# Out:
# 30

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Purpose'].unique()
# Out:
# array(['Earth Observation', 'Technology Development', 'Communications',
#        'Earth Science', 'Space Science',
#        'Space Science/Technology Demonstration',
#        'Communications/Technology Development',
#        'Communications/Maritime Tracking', 'Technology Demonstration',
#        'Unknown', 'Navigation/Global Positioning',
#        'Earth Observation/Technology Development',
#        'Earth Observation/Communications', 'Earth/Space Observation',
#        'Educational', 'Earth Observation/Earth Science', 'Platform',
#        'Earth Observation/Space Science', 'Earth Observation/Navigation',
#        'Communications/Navigation', 'Space Observation', 'Surveillance',
#        'Navigation/Regional Positioning',
#        'Space Science/Technology Development',
#        'Mission Extension Technology', 'Earth Science/Earth Observation',
#        'Earth Observation/Communications/Space Science', 'Meteorological',
# ...

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Detailed Purpose'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Detailed Purpose'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Detailed Purpose'].nunique()
# Out:
# 54

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Class of Orbit'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Class of Orbit'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Class of Orbit'].nunique()
# Out:
# 5

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Class of Orbit'].unique()
# Out:
# array(['LEO', 'GEO', 'Elliptical', 'MEO', 'LEo'], dtype=object)

# %%
#Replace the inconsistencies in the column  
df_dropped_3['Class of Orbit'] = df_dropped_3['Class of Orbit'].replace('LEo', 'LEO')

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Class of Orbit'].unique()
# Out:
# array(['LEO', 'GEO', 'Elliptical', 'MEO'], dtype=object)

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Type of Orbit'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Type of Orbit'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Type of Orbit'].nunique()
# Out:
# 11

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Type of Orbit'].unique()
# Out:
# array(['Non-Polar Inclined', 'Sun-Synchronous', 'nan', 'Equatorial',
#        'Polar', 'Elliptical', 'Deep Highly Eccentric', 'Molniya',
#        'Retrograde', 'Cislunar', 'Sun-Synchronous near polar'],
#       dtype=object)

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Period (minutes)'].count()
# Out:
# 7504

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Period (minutes)'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Period (minutes)'].nunique()
# Out:
# 578

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Launch Mass (kg.)'].count()
# Out:
# 7315

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Launch Mass (kg.)'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Launch Mass (kg.)'].nunique()
# Out:
# 595

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Dry Mass (kg.)'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Dry Mass (kg.)'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Dry Mass (kg.)'].nunique()
# Out:
# 205

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Power (watts)'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Power (watts)'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Power (watts)'].nunique()
# Out:
# 153

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Date of Launch'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Date of Launch'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Date of Launch'].nunique()
# Out:
# 1223

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Expected Lifetime (yrs.)'].count()
# Out:
# 5450

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Expected Lifetime (yrs.)'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Expected Lifetime (yrs.)'].nunique()
# Out:
# 28

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Contractor'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Contractor'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Contractor'].nunique()
# Out:
# 568

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Country of Contractor'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Country of Contractor'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Contractor'].nunique()
# Out:
# 99

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Contractor'].unique()
# Out:
# array(['USA', 'Sweden/UK/USA/Netherlands', 'Finland', 'Denmark', 'Israel',
#        'France/UK/Germany/Spain', 'France', 'Canada', 'Norway/Canada',
#        'Kazakhstan', 'China', 'Japan', 'Brazil', 'UK', 'France/Italy',
#        'Russia', 'ESA', 'Argentina', 'Norway', 'Belgium', 'Turkey',
#        'France/UK/Germany', 'Germany/France', 'Switzerland', 'Swizerland',
#        'India', 'Singapore', 'France/Belgium/Spain/Italy',
#        'Czech Republic', 'Germany', 'China/UK', 'China/France',
#        'Norway/Netherlands', 'Lithuania', 'Netherlands', 'Poland',
#        'Australia', 'South Korea', 'Tunisia', 'ESA/EADS CASA Espacio',
#        'Italy', 'United Arab Emirates', 'Philippines', 'Ecuador',
#        'Singapore/UK', 'South Africa', 'Japan/Brazil', 'Luxembourg',
#        'China/Ethiopia', 'Russia/France', 'Taiwan', 'UK/Netherlands',
#        'Germany/UK', 'Germany/UK/Italy', 'Denmark/Canada',
#        'Japan/UK/Germany', 'International', 'UK/France/Germany/Spain',
# ...

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Contractor'].value_counts().sort_index()
# Out:
# Country of Contractor
# Argentina                          45
# Australia                          10
# Austria                             1
# Belgium                             5
# Brazil                              6
# Bulgaria                            2
# Canada                             42
# Canada/Italy                        1
# Chile                               2
# China                             630
# China/Austria                       1
# China/Ethiopia                      1
# China/France                        2
# China/Italy                         1
# China/UK                            1
# Czech Republic                      3
# Denmark                            23
# Denmark/Canada                      3
# ESA                                 4
# ESA/EADS CASA Espacio               1
# Ecuador                             1
# Egypt                               1
# Estonia                             1
# Finland                            26
# ...

# %%
#Create a list of --Multi-- from --Country of Operator/Owner--
multinational_Contractors = ['China/Brazil','Canada/Italy','China/Austria','China/Ethiopia','China/France',
                             'China/Italy','China/UK','ESA','ESA/EADS CASA Espacio','France/Belgium/Spain/Italy',
                             'France/Germany/Space','France/Italy','France/Netherlands','France/UK/Germany',
                             'France/UK/Germany/Spain','France/UK/Germany/Spain/Italy','France/UK/Spain',
                             'Germany/France','Germany/UK','Germany/UK/France/Spain','Germany/UK/Italy',
                             'International','Italy/Germany','Italy/International','Japan/Brazil','UK/Canada',
                             'Japan/UK/Germany','Kenya/Bulgaria','Morocco/Germany','Multinational',
                             'Norway/Canada','Norway/Netherlands','Russia/France','Russia/USA','Singapore/UK',
                             'South Korea/France/UK/Germany','Sweden/Canada/Finland/France','Sweden/UK/USA/Netherlands',
                             'UK/Finland/Belgium','UK/France/Germany/Spain','UK/Netherlands','USA/Germany']

# %%
#Check the list
multinational_Contractors
# Out:
# ['China/Brazil',
#  'Canada/Italy',
#  'China/Austria',
#  'China/Ethiopia',
#  'China/France',
#  'China/Italy',
#  'China/UK',
#  'ESA',
#  'ESA/EADS CASA Espacio',
#  'France/Belgium/Spain/Italy',
#  'France/Germany/Space',
#  'France/Italy',
#  'France/Netherlands',
#  'France/UK/Germany',
#  'France/UK/Germany/Spain',
#  'France/UK/Germany/Spain/Italy',
#  'France/UK/Spain',
#  'Germany/France',
#  'Germany/UK',
#  'Germany/UK/France/Spain',
#  'Germany/UK/Italy',
#  'International',
#  'Italy/Germany',
#  'Italy/International',
#  'Japan/Brazil',
#  'UK/Canada',
#  'Japan/UK/Germany',
#  'Kenya/Bulgaria',
#  'Morocco/Germany',
#  'Multinational',
#  'Norway/Canada',
#  'Norway/Netherlands',
#  'Russia/France',
#  'Russia/USA',
#  'Singapore/UK',
#  'South Korea/France/UK/Germany',
#  'Sweden/Canada/Finland/France',
#  'Sweden/UK/USA/Netherlands',
#  'UK/Finland/Belgium',
#  'UK/France/Germany/Spain',
#  'UK/Netherlands',
#  'USA/Germany']

# %%
#Replace the list with --Multinational-- and update the dataframe 
df_dropped_3['Country of Contractor'] = df_dropped_3['Country of Contractor'].replace(multinational_Contractors ,'Multinational')

# %%
#Check the data frame
df_dropped_3['Country of Contractor'].unique()
# Out:
# array(['USA', 'Multinational', 'Finland', 'Denmark', 'Israel', 'France',
#        'Canada', 'Kazakhstan', 'China', 'Japan', 'Brazil', 'UK', 'Russia',
#        'Argentina', 'Norway', 'Belgium', 'Turkey', 'Switzerland',
#        'Swizerland', 'India', 'Singapore', 'Czech Republic', 'Germany',
#        'Lithuania', 'Netherlands', 'Poland', 'Australia', 'South Korea',
#        'Tunisia', 'Italy', 'United Arab Emirates', 'Philippines',
#        'Ecuador', 'South Africa', 'Luxembourg', 'Taiwan',
#        'Denmark/Canada', 'Malaysia', 'Jordan', 'Saudi Arabia', 'Kuwait',
#        'Indonesia', 'Spain', 'Vietnam', 'Egypt', 'Iran', 'Sweden',
#        'Uruguay', 'Mexico', 'New Zealand', 'Ukraine', 'Hungary', 'Monaco',
#        'Nepal', 'Bulgaria', 'Chile', 'Slovenia', 'Estonia', 'Austria'],
#       dtype=object)

# %%
#Replace the other inconsistencies in the column  
df_dropped_3['Country of Contractor'] = df_dropped_3['Country of Contractor'].replace({'China ': 'China',
                                                                                       'United Arab Emirates':'UAE',
                                                                                       'Swizerland': 'Switzerland'})

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Country of Contractor'].value_counts().sort_index()
# Out:
# Country of Contractor
# Argentina           45
# Australia           10
# Austria              1
# Belgium              5
# Brazil               6
# Bulgaria             2
# Canada              42
# Chile                2
# China              630
# Czech Republic       3
# Denmark             23
# Denmark/Canada       3
# Ecuador              1
# Egypt                1
# Estonia              1
# Finland             26
# France              97
# Germany             47
# Hungary              2
# India               63
# Indonesia            2
# Iran                 1
# Israel              29
# Italy               49
# Japan               77
# Jordan               1
# Kazakhstan           1
# Kuwait               1
# Lithuania            4
# Luxembourg          17
# Malaysia             1
# Mexico               3
# Monaco               1
# Multinational      239
# Nepal                1
# Netherlands         11
# New Zealand          1
# Norway               5
# Philippines          1
# ...

# %%
#Check the data frame
df_dropped_3['Country of Contractor'].unique()
# Out:
# array(['USA', 'Multinational', 'Finland', 'Denmark', 'Israel', 'France',
#        'Canada', 'Kazakhstan', 'China', 'Japan', 'Brazil', 'UK', 'Russia',
#        'Argentina', 'Norway', 'Belgium', 'Turkey', 'Switzerland', 'India',
#        'Singapore', 'Czech Republic', 'Germany', 'Lithuania',
#        'Netherlands', 'Poland', 'Australia', 'South Korea', 'Tunisia',
#        'Italy', 'UAE', 'Philippines', 'Ecuador', 'South Africa',
#        'Luxembourg', 'Taiwan', 'Denmark/Canada', 'Malaysia', 'Jordan',
#        'Saudi Arabia', 'Kuwait', 'Indonesia', 'Spain', 'Vietnam', 'Egypt',
#        'Iran', 'Sweden', 'Uruguay', 'Mexico', 'New Zealand', 'Ukraine',
#        'Hungary', 'Monaco', 'Nepal', 'Bulgaria', 'Chile', 'Slovenia',
#        'Estonia', 'Austria'], dtype=object)

# %%
#Check the data frame
df_dropped_3['Country of Contractor'].nunique()
# Out:
# 58

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Launch Site'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Launch Site'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Launch Site'].nunique()
# Out:
# 40

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Launch Site'].unique()
# Out:
# array(['Satish Dhawan Space Centre', 'Cape Canaveral',
#        'Guiana Space Center', 'Baikonur Cosmodrome', 'Vandenberg AFB',
#        'Rocket Lab Launch Complex 1', 'Cygnus', 'Dombarovsky Air Base',
#        'Xichang Satellite Launch Center', 'Vostochny Cosmodrome',
#        'Uchinoura Space Center', 'Jiuquan Satellite Launch Center',
#        'Plesetsk Cosmodrome', 'Taiyuan Launch Center', 'Virgin Orbit',
#        'Vandeberg AFB', 'Yellow Sea Launch Platform',
#        'FANTM-RAiL [Xtenti]',
#        'Mid-Atlantic Regional Spaceport/Wallops Island',
#        'Wenchang Space Center', 'Orbital ATK L-1011',
#        'Tanegashima Space Center', 'International Space Station',
#        'Antares', 'Sea Launch Odyssey', 'Svobodny Cosmodrome',
#        'Kodiak Launch Complex', 'Wallops Island Flight Facility',
#        'Stargazer L-1011', 'Kwajalein Island', 'Taiyan Launch Center',
#        'International Space Station - Cygnus', 'Shahroud Missile Range',
# ...

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Launch Vehicle'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Launch Vehicle'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Launch Vehicle'].nunique()
# Out:
# 163

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Launch Vehicle'].unique()
# Out:
# array(['PSLV', 'Falcon 9', 'Soyuz-2.1a', 'Ariane 5 ECA', 'Atlas 3',
#        'Proton', 'Delta 4 Heavy', 'Titan IVA', 'Titan IV', 'Atlas 5',
#        'Vega', 'Electron', 'Nanorack Deployer', 'Dnepr', 'Ariane 5',
#        'Vega W18', 'Pegasus XL', 'Soyuz-2.1b', 'Long March 3B',
#        'Atlas 2AS', 'Proton M', 'Proton K', 'Zenit 3SLB', 'Zenit 2SB',
#        'Delta 2310', 'Soyuz', 'Ariane 44L', 'Falcon Heavy',
#        'Falcon 9/Sherpa FX', 'H2A', 'Breeze M', 'Ariane 5G', 'Epsilon',
#        'PSLV C-30', 'PSLV-C29', 'Ceres 1', 'Long March 3C',
#        'Long March 3A', 'Long March 2D', 'Kosmos 3M', 'PSLV C3',
#        'PSLV XL', 'Soyuz-Fregat', 'Ariane 44LP', 'LauncherOne',
#        'Long March 2B', 'Delta 2', 'Long March 11', 'PSLV C9', 'PSLV-CA',
#        'PSLV C6', 'PSLV C7', 'Long March 4B', 'Kuaizhou', 'Long March 2C',
#        'Space Shuttle (STS 93)', 'Long March 8', 'Kuaizhou-1A',
#        'SEOPS Slingshot Deployer', 'PSLV-XL', 'Titan 2', 'Soyuz-2',
# ...

# %%
df_dropped_3.shape
# Out:
# (7560, 19)

# %%
#Check the count of vlaues of the columns (without NA)
df_dropped_3['Date of Launch'].count()
# Out:
# 7560

# %%
#Check the count of vlaues of the columns (with NA)
df_dropped_3['Date of Launch'].size
# Out:
# 7560

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Date of Launch'].nunique()
# Out:
# 1223

# %%
#Check the unique vlaues of the columns 
df_dropped_3['Date of Launch'].nunique()
# Out:
# 1223

# %%
#Check the dataframe
df_dropped_3.shape
# Out:
# (7560, 19)

# %%
#Check the dataframe for duplicated values
df_dropped_3[df_dropped_3.duplicated()]
# Out:
#      ID Number COSPAR Satellite Name Country of Operator/Owner Operator/Owner  \
# 6204       2023-046BC  Starlink-5016                       USA         SpaceX
# 6272       2023-046BH  Starlink-5089                       USA         SpaceX
# 6294       2023-046BF  Starlink-5111                       USA         SpaceX
# 6323       2023-046BG  Starlink-5140                       USA         SpaceX
# 6519       2023-046BE  Starlink-5370                       USA         SpaceX
# 6523       2023-046BD  Starlink-5374                       USA         SpaceX
# 6526       2023-046BB  Starlink-5376                       USA         SpaceX
# 6623        2022-175K  Starlink-5472                       USA         SpaceX
#
#      Country of Contractor Contractor       Users         Purpose  \
# 6204                   USA     SpaceX  Commercial  Communications
# 6272                   USA     SpaceX  Commercial  Communications
# 6294                   USA     SpaceX  Commercial  Communications
# ...

# %%
#Create a subset of the dataframe -df_dropped_3 that only contains rows with duplicates. 
df_dropped_3_dups = df_dropped_3[df_dropped_2.duplicated()]

# %%
#Check the dimensions 
df_dropped_3_dups.shape
# Out:
# (8, 19)

# %%
#Create a new dataframe that doesn’t contains duplicates (Dropping duplicates)
df_dropped_3_no_dups = df_dropped_3.drop_duplicates()

# %%
#Check the dimensions 
df_dropped_3_no_dups.shape
# Out:
# (7552, 19)

# %%
#Find missing values
df_dropped_3_no_dups.isnull().sum()
# Out:
# ID Number COSPAR                0
# Satellite Name                  0
# Country of Operator/Owner       0
# Operator/Owner                  0
# Country of Contractor           0
# Contractor                      0
# Users                           0
# Purpose                         0
# Detailed Purpose                0
# Class of Orbit                  0
# Type of Orbit                   0
# Period (minutes)               56
# Expected Lifetime (yrs.)     2110
# Date of Launch                  0
# Launch Mass (kg.)             245
# Dry Mass (kg.)                  0
# Power (watts)                   0
# Launch Site                     0
# Launch Vehicle                  0
# dtype: int64

# %%
#Create a subset of the dataframe -df_nan that only contains rows with missing value. 
df_nan = df_dropped_3_no_dups[df_dropped_3_no_dups[['Period (minutes)', 'Launch Mass (kg.)', 'Expected Lifetime (yrs.)']].isnull() == True]

# %%
#Check the dimensions 
df_nan.shape
# Out:
# (7552, 19)

# %%
#Check the row of one of the Satellite 
df_dropped_3_no_dups[df_dropped_3_no_dups['ID Number COSPAR'] == '2023-041C']
# Out:
#     ID Number COSPAR     Satellite Name Country of Operator/Owner  \
# 240        2023-041C  BlackSky Global 5                       USA
#
#       Operator/Owner Country of Contractor Contractor       Users  \
# 240  BlackSky Global                   USA  LeoStella  Commercial
#
#                Purpose Detailed Purpose Class of Orbit       Type of Orbit  \
# 240  Earth Observation  Optical Imaging            LEO  Non-Polar Inclined
#
#      Period (minutes)  Expected Lifetime (yrs.) Date of Launch  \
# 240               NaN                       NaN            NaT
#
#      Launch Mass (kg.) Dry Mass (kg.) Power (watts)  \
# 240                NaN            nan           nan
#
#                      Launch Site Launch Vehicle
# 240  Rocket Lab Launch Complex 1       Electron

# %%
#Drop a row -Satellite ID 2023-041C- due to multi missing values
df_dropped_3_no_dups = df_dropped_3_no_dups[df_dropped_3_no_dups['ID Number COSPAR'] != '2023-041C']

# %%
#Check the dimensions 
df_dropped_3_no_dups.shape
# Out:
# (7551, 19)

# %%
#Check the dataframe for missing values
df_dropped_3_no_dups.isnull().sum()
# Out:
# ID Number COSPAR                0
# Satellite Name                  0
# Country of Operator/Owner       0
# Operator/Owner                  0
# Country of Contractor           0
# Contractor                      0
# Users                           0
# Purpose                         0
# Detailed Purpose                0
# Class of Orbit                  0
# Type of Orbit                   0
# Period (minutes)               55
# Expected Lifetime (yrs.)     2109
# Date of Launch                  0
# Launch Mass (kg.)             244
# Dry Mass (kg.)                  0
# Power (watts)                   0
# Launch Site                     0
# Launch Vehicle                  0
# dtype: int64

# %%
#Check the missing values in the 'Launch Mass (kg.)' baed on Class of Orbit.
df_dropped_3_no_dups[df_dropped_3_no_dups['Launch Mass (kg.)'].isnull()].groupby('Class of Orbit').size()
# Out:
# Class of Orbit
# Elliptical      7
# GEO            36
# LEO           200
# MEO             1
# dtype: int64

# %%
#Get the Average values of the --Launch Mass-- within the --Class Orbit
df_dropped_3_no_dups.groupby('Class of Orbit').agg({'Launch Mass (kg.)': ['mean', 'min', 'max']})
# Out:
#                Launch Mass (kg.)
#                             mean    min      max
# Class of Orbit
# Elliptical           1898.126923    5.0   8000.0
# GEO                  4083.953069  100.0   8429.0
# LEO                   311.093894    0.5  22500.0
# MEO                  1250.514085  600.0   4352.0

# %%
#Fill the NaN values of the --Launch Mass-- within the --Elliptical Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'Elliptical', 'Launch Mass (kg.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'Elliptical', 'Launch Mass (kg.)'].fillna(1898)

# %%
#Fill the NaN values of the --Launch Mass-- within the --GEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Launch Mass (kg.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Launch Mass (kg.)'].fillna(4083)

# %%
#Fill the NaN values of the --Launch Mass-- within the --GEO Orbit and assign to a new dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Launch Mass (kg.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Launch Mass (kg.)'].fillna(311)

# %%
#Fill the NaN values of the --Launch Mass-- within the --MEO Orbit and assign to a new dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'MEO', 'Launch Mass (kg.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'MEO', 'Launch Mass (kg.)'].fillna(1250)

# %%
#Check the dataframe for missing values
df_dropped_3_no_dups.isnull().sum()
# Out:
# ID Number COSPAR                0
# Satellite Name                  0
# Country of Operator/Owner       0
# Operator/Owner                  0
# Country of Contractor           0
# Contractor                      0
# Users                           0
# Purpose                         0
# Detailed Purpose                0
# Class of Orbit                  0
# Type of Orbit                   0
# Period (minutes)               55
# Expected Lifetime (yrs.)     2109
# Date of Launch                  0
# Launch Mass (kg.)               0
# Dry Mass (kg.)                  0
# Power (watts)                   0
# Launch Site                     0
# Launch Vehicle                  0
# dtype: int64

# %%
#Check the missing values in the 'Expected Lifetime (yrs.)' baed on Class of Orbit.
df_dropped_3_no_dups[df_dropped_3_no_dups['Expected Lifetime (yrs.)'].isnull()].groupby('Class of Orbit').size()
# Out:
# Class of Orbit
# Elliptical      25
# GEO             97
# LEO           1965
# MEO             22
# dtype: int64

# %%
#Get the Average values of the --Expected Lifetime-- within the --Class of Orbit
df_dropped_3_no_dups.groupby('Class of Orbit').agg({'Expected Lifetime (yrs.)': ['mean', 'min', 'max']})
# Out:
#                Expected Lifetime (yrs.)
#                                    mean   min   max
# Class of Orbit
# Elliptical                     6.852941  1.00  20.0
# GEO                           13.773834  2.00  30.0
# LEO                            4.369681  0.25  30.0
# MEO                            9.553719  1.00  15.0

# %%
#Fill the NaN values of the --Expected Lifetime-- within the --Elliptical Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'Elliptical', 'Expected Lifetime (yrs.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'Elliptical', 'Expected Lifetime (yrs.)'].fillna(6)

# %%
#Fill the NaN values of the --Expected Lifetime-- within the --GEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Expected Lifetime (yrs.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Expected Lifetime (yrs.)'].fillna(13)

# %%
#Fill the NaN values of the --Expected Lifetime-- within the --LEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Expected Lifetime (yrs.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Expected Lifetime (yrs.)'].fillna(4)

# %%
#Fill the NaN values of the --Expected Lifetime-- within the --MEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'MEO', 'Expected Lifetime (yrs.)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'MEO', 'Expected Lifetime (yrs.)'].fillna(9)

# %%
#Check the dataframe for missing values
df_dropped_3_no_dups.isnull().sum()
# Out:
# ID Number COSPAR              0
# Satellite Name                0
# Country of Operator/Owner     0
# Operator/Owner                0
# Country of Contractor         0
# Contractor                    0
# Users                         0
# Purpose                       0
# Detailed Purpose              0
# Class of Orbit                0
# Type of Orbit                 0
# Period (minutes)             55
# Expected Lifetime (yrs.)      0
# Date of Launch                0
# Launch Mass (kg.)             0
# Dry Mass (kg.)                0
# Power (watts)                 0
# Launch Site                   0
# Launch Vehicle                0
# dtype: int64

# %%
#Check the dataframe
df_dropped_3_no_dups.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1                        UK                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#   Country of Contractor             Contractor       Users  \
# 0                   USA           Hera Systems  Commercial
# 1         Multinational        AAC Clyde Space  Commercial
# ...

# %%
#Check the missing values in the --Period (minutes)-- baed on Class of Orbit.
df_dropped_3_no_dups[df_dropped_3_no_dups['Period (minutes)'].isnull()].groupby('Class of Orbit').size()
# Out:
# Class of Orbit
# GEO     5
# LEO    50
# dtype: int64

# %%
#Get the Average values of the --Period (minutes)-- within the --class of Orbit
df_dropped_3_no_dups.groupby('Class of Orbit').agg({'Period (minutes)': ['mean', 'min', 'max']})
# Out:
#                Period (minutes)
#                            mean   min       max
# Class of Orbit
# Elliptical          1587.560678  93.9  11520.00
# GEO                 1437.209094  98.3   5585.00
# LEO                   96.772479   9.0   1436.10
# MEO                  675.325315  97.7    860.51

# %%
#Fill the NaN values of the --Period (minutes)-- within the --GEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Period (minutes)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'GEO', 'Period (minutes)'].fillna(1437.20)

# %%
#Fill the NaN values of the --Period (minutes)-- within the --LEO Orbit and update the dataframe
df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Period (minutes)'] = df_dropped_3_no_dups.loc[df_dropped_3_no_dups['Class of Orbit'] == 'LEO', 'Period (minutes)'].fillna(96.77)

# %%
#Check the dataframe for missing values
df_dropped_3_no_dups.isnull().sum()
# Out:
# ID Number COSPAR             0
# Satellite Name               0
# Country of Operator/Owner    0
# Operator/Owner               0
# Country of Contractor        0
# Contractor                   0
# Users                        0
# Purpose                      0
# Detailed Purpose             0
# Class of Orbit               0
# Type of Orbit                0
# Period (minutes)             0
# Expected Lifetime (yrs.)     0
# Date of Launch               0
# Launch Mass (kg.)            0
# Dry Mass (kg.)               0
# Power (watts)                0
# Launch Site                  0
# Launch Vehicle               0
# dtype: int64

# %%
#Check the dimensions 
df_dropped_3_no_dups.shape
# Out:
# (7551, 19)

# %%
#Check the --Date of Launch-- variable 
df_dropped_3_no_dups['Date of Launch'].dtype
# Out:
# dtype('O')

# %%
#Check the frequency  
df_dropped_3_no_dups['Date of Launch'].value_counts()

#Formating issues exist
# Out:
# Date of Launch
# 2023-01-03 00:00:00    93
# 2021-01-24 00:00:00    89
# 2022-01-13 00:00:00    85
# 2021-06-30 00:00:00    77
# 2021-03-11 00:00:00    60
# 2021-04-07 00:00:00    60
# 2021-04-28 00:00:00    60
# 2021-05-04 00:00:00    60
# 2021-05-26 00:00:00    60
# 2020-06-13 00:00:00    60
# 2021-05-09 00:00:00    59
# 2022-04-29 00:00:00    59
# 2021-02-15 00:00:00    58
# 2021-01-20 00:00:00    58
# 2021-03-14 00:00:00    58
# 2020-08-18 00:00:00    58
# 2020-08-07 00:00:00    57
# 2020-03-18 00:00:00    57
# 2023-03-24 00:00:00    57
# 2023-03-29 00:00:00    57
# 2021-02-04 00:00:00    57
# 2020-06-03 00:00:00    56
# 2021-03-04 00:00:00    56
# 2023-03-17 00:00:00    55
# 2023-01-26 00:00:00    55
# 2022-12-28 00:00:00    54
# 2022-10-04 00:00:00    54
# 2020-04-22 00:00:00    54
# 2022-12-17 00:00:00    54
# 2023-02-12 00:00:00    54
# 2022-09-24 00:00:00    54
# 2022-05-13 00:00:00    53
# 2022-07-17 00:00:00    53
# 2022-05-14 00:00:00    53
# 2022-10-20 00:00:00    53
# ...

# %%
#Replace the "incorrect format" and update the dataframe
#Change some of the values in 'Date of Launch' columns to make them consistent

df_dropped_3_no_dups['Date of Launch'] = df_dropped_3_no_dups['Date of Launch'].replace({'11/29/018':'11-29-2018',
                                                                         '1/9//2023':'01-09-2023'})

# %%
#Check the frequency  
df_dropped_3_no_dups['Date of Launch'].value_counts()
# Out:
# Date of Launch
# 2023-01-03 00:00:00    93
# 2021-01-24 00:00:00    89
# 2022-01-13 00:00:00    85
# 2021-06-30 00:00:00    77
# 2021-03-11 00:00:00    60
# 2021-04-07 00:00:00    60
# 2021-04-28 00:00:00    60
# 2021-05-04 00:00:00    60
# 2021-05-26 00:00:00    60
# 2020-06-13 00:00:00    60
# 2021-05-09 00:00:00    59
# 2022-04-29 00:00:00    59
# 2021-02-15 00:00:00    58
# 2021-01-20 00:00:00    58
# 2021-03-14 00:00:00    58
# 2020-08-18 00:00:00    58
# 2020-08-07 00:00:00    57
# 2020-03-18 00:00:00    57
# 2023-03-24 00:00:00    57
# 2023-03-29 00:00:00    57
# 2021-02-04 00:00:00    57
# 2020-06-03 00:00:00    56
# 2021-03-04 00:00:00    56
# 2023-03-17 00:00:00    55
# 2023-01-26 00:00:00    55
# 2022-12-28 00:00:00    54
# 2022-10-04 00:00:00    54
# 2020-04-22 00:00:00    54
# 2022-12-17 00:00:00    54
# 2023-02-12 00:00:00    54
# 2022-09-24 00:00:00    54
# 2022-05-13 00:00:00    53
# 2022-07-17 00:00:00    53
# 2022-05-14 00:00:00    53
# 2022-10-20 00:00:00    53
# ...

# %%
#Check the frequency  
df_dropped_3_no_dups['Date of Launch'].count()
# Out:
# 7551

# %%
#Check the frequency  
df_dropped_3_no_dups['Date of Launch'].nunique()
# Out:
# 1222

# %%
#Convert the column to a datetime Type 
df_dropped_3_no_dups['Date of Launch'] = pd.to_datetime(df_dropped_3_no_dups['Date of Launch'])

# %%
#Check the datatype  
df_dropped_3_no_dups['Date of Launch'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Check the datatype  
df_dropped_3_no_dups.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1                        UK                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#   Country of Contractor             Contractor       Users  \
# 0                   USA           Hera Systems  Commercial
# 1         Multinational        AAC Clyde Space  Commercial
# ...

# %%
#Separate into year, month, and day components
df_dropped_3_no_dups['Launch Year'] = df_dropped_3_no_dups['Date of Launch'].dt.year

# %%
#Separate into year, month, day, and day components
df_dropped_3_no_dups['Launch Month'] = df_dropped_3_no_dups['Date of Launch'].dt.month

# %%
#Separate into year, month, day, and day components
df_dropped_3_no_dups['Launch Day'] = df_dropped_3_no_dups['Date of Launch'].dt.day

# %%
#Check the column
df_dropped_3_no_dups.head(10)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
# 5        2016-038A                                             ABS-2A
# 6        2015-010A                                             ABS-3A
# 7        2004-007A  ABS-4 (ABS-2i, MBSat, Mobile Broadcasting Sate...
# 8        1999-053A  ABS-6 (ABS-1, LMI-1, Lockheed Martin-Intersput...
# 9        2021-022F                                   Adelis-Sampson 1
#
#   Country of Operator/Owner  \
# 0                       USA
# 1                        UK
# 2                   Finland
# 3                   Denmark
# 4             Multinational
# ...

# %%
#Check the Date variable
df_dropped_3_no_dups['Date of Launch'].head(10)
# Out:
# 0   2019-12-11
# 1   2023-01-03
# 2   2017-06-23
# 3   2016-04-25
# 4   2014-02-06
# 5   2016-06-15
# 6   2015-03-02
# 7   2004-03-13
# 8   1999-09-26
# 9   2021-03-22
# Name: Date of Launch, dtype: datetime64[ns]

# %%
df_dropped_3_no_dups['Date of Launch'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Check the dimensions 
df_dropped_3_no_dups.shape
# Out:
# (7551, 22)

# %%
#Create a dataframe to filter out the --Date and time-- columns
#A list of columns to drop
columns_to_drop_3 = ['Date of Launch', 'Launch Day']

# %%
#Check the list
columns_to_drop_3
# Out:
# ['Date of Launch', 'Launch Day']

# %%
#Drop the list of columns from the dataframe and assign it to a new dataframe
df_clean = df_dropped_3_no_dups.drop(columns= columns_to_drop_3)

# %%
#Check the dataframe
df_clean.head(5)
# Out:
#   ID Number COSPAR                                     Satellite Name  \
# 0        2019-089H  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1       2023-001DC                            AAC AIS-Sat1 (Kelpie 1)
# 2        2017-036L                                            Aalto-1
# 3        2016-025E                                              AAt-4
# 4        2014-006A                           ABS-2 (Koreasat-8, ST-3)
#
#   Country of Operator/Owner                 Operator/Owner  \
# 0                       USA                   Hera Systems
# 1                        UK                AAC Clyde Space
# 2                   Finland               Aalto University
# 3                   Denmark          University of Aalborg
# 4             Multinational  Asia Broadcast Satellite Ltd.
#
#   Country of Contractor             Contractor       Users  \
# 0                   USA           Hera Systems  Commercial
# 1         Multinational        AAC Clyde Space  Commercial
# ...

# %%
#Check the dataframe
df_clean.shape
# Out:
# (7551, 20)

# %%
#Check the total number of unique vlaues of the columns 
df_clean['Launch Year'].unique()
# Out:
# array([2019, 2023, 2017, 2016, 2014, 2015, 2004, 1999, 2021, 2020, 1998,
#        2003, 2009, 2010, 2012, 2013, 2018, 2008, 2007, 2022, 2006, 2000,
#        1974, 2005, 2011, 1997, 2001, 2002, 1995, 1989, 1992, 1990, 1996,
#        1994, 1993, 1988, 1991], dtype=int32)

# %%
#Check the total number of unique vlaues of the columns 
df_clean['Launch Year'].nunique()
# Out:
# 37

# %%
#Check the total number of unique vlaues of the columns 
df_clean['Launch Month'].unique()
# Out:
# array([12,  1,  6,  4,  2,  3,  9,  5, 11, 10,  8,  7], dtype=int32)

# %%
#Check the total number of unique vlaues of the columns 
df_clean['Launch Month'].nunique()
# Out:
# 12

# %%
#Check the datatypes of all the columns 
df_clean.dtypes
# Out:
# ID Number COSPAR              object
# Satellite Name                object
# Country of Operator/Owner     object
# Operator/Owner                object
# Country of Contractor         object
# Contractor                    object
# Users                         object
# Purpose                       object
# Detailed Purpose              object
# Class of Orbit                object
# Type of Orbit                 object
# Period (minutes)             float64
# Expected Lifetime (yrs.)     float64
# Launch Mass (kg.)            float64
# Dry Mass (kg.)                object
# Power (watts)                 object
# Launch Site                   object
# Launch Vehicle                object
# Launch Year                    int32
# Launch Month                   int32
# dtype: object

# %%
#Check the dataframe
df_clean.shape
# Out:
# (7551, 20)

# %% [markdown]
# # 06. Summary Statistics

# %%
#Check the statistics of the varaibles -descriptive statistics
df_clean.describe()
# Out:
#        Period (minutes)  Expected Lifetime (yrs.)  Launch Mass (kg.)  \
# count       7551.000000               7551.000000        7551.000000
# mean         224.112830                  5.111475         636.071308
# std          441.326798                  3.107859        1386.523750
# min            9.000000                  0.250000           0.500000
# 25%           95.000000                  4.000000         148.000000
# 50%           95.600000                  4.000000         260.000000
# 75%           96.600000                  4.000000         290.000000
# max        11520.000000                 30.000000       22500.000000
#
#        Launch Year  Launch Month
# count  7551.000000   7551.000000
# mean   2019.456893      5.952721
# std       4.682838      3.570670
# min    1974.000000      1.000000
# 25%    2019.000000      3.000000
# 50%    2021.000000      5.000000
# 75%    2022.000000      9.000000
# max    2023.000000     12.000000

# %%
#Check the Mode of the variables 
df_clean['Users'].mode()

###All the variables were checked (Users, Class of Orbit, Country of Contractor, Country of Operator/Owner)
# Out:
# 0    Commercial
# Name: Users, dtype: object

# %%
#Check the Mode of the variables 
df_clean['Class of Orbit'].mode()
# Out:
# 0    LEO
# Name: Class of Orbit, dtype: object

# %%
#Check the Mode of the variables 
df_clean['Country of Contractor'].mode()
# Out:
# 0    USA
# Name: Country of Contractor, dtype: object

# %%
#Check the Mode of the variables 
df_clean['Country of Operator/Owner'].mode()
# Out:
# 0    USA
# Name: Country of Operator/Owner, dtype: object

# %%
#Check the dataset
df_clean.shape
# Out:
# (7551, 20)

# %% [markdown]
# # 07. Exporting Data

# %%
# Export the cleaned dataframe to Prepared-Data
df_clean.to_csv(os.path.join(path, '02-Data','Prepared-Data', 'Satellite_clean.csv'))

# %% [markdown]
# # 08. Observations

# %% [markdown]
# ++++++++++++++Coding Workflow++++++++++++++
#
# ## The dataset contains —df— 7560 rows and 68 columns
#
# + The number of columns does not match initial expectations.
# + Upon reviewing the variables, several columns are labeled as "Unnamed."
# + Some rows contain the value "Estimated" without columns assigned.
# + According to the User's Guide for the UCS Satellite Database, the term "Estimated" indicates that orbital data for some military satellites is either estimated or sourced from specific websites.
#
# ## Summary statistics:
#
# + Summary statistics show that not all variables have the same count. This requires further study.
# + The Expected Lifetime: OK
# + The Launch Mass: significant variation in the data.
# + The Period: significant variation in the data.
#
# ## Dropping columns:
#
#
# + I have dropped all the columns that do not have any values in the analysis.
# + I dropped all the "Source" and "Unnamed" columns, resulting in a total of 40 columns being removed.
# + The dataset contains —df_dropped— 7560 rows and 28 columns.
# + Further, I dropped columns that are not relevant to the analysis based on the questions I have formulated.
# + The dropped columns are: ['Current Official Name of Satellite', 'Country/Org of UN Registry', 'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)', 'Eccentricity', 'Inclination (degrees)', 'NORAD Number', 'Comments'].
#
# ## The dataset contains —df_dropped_2— 7560 rows and 19 columns.
#
# ## Renaming columns:
#
# + I renamed some columns for clarity: [Name of Satellite, Alternate Names, ID Number COSPAR]
#
# ## Reordering columns
#
# + Reordered the columns and assigned it to a new data frame
#
# ## The dataset contains —df_dropped_2_reorder— 7560 rows and 19 columns
#
# ## White Spaces and DataTypes Check
#
# ## The dataset contains —df_dropped_3— 7560 rows and 19 columns
#
# + I converted all the variables, including non-string variables, to a string data type, removed the white spaces, and assigned them to a new dataframe.
# + I reverted the non-string variables to a float data type and assigned them to a new dataframe.
# + I checked the columns for any mixed data types. No mixed data types were found.
# + I assigned the new changes to a new dataframe.
#
# ## The dataset contains —df_dropped_3— 7560 rows and 19 columns.
#
# ## Consistency Checks
#
# + ID Number COSPAR:
# + The count values = 7560
# + unique values = 7537
# + There are duplicates, but no missing values.
#
# + Satellite Name:
# + The count values = 7560
# + unique values = 7543
# + There are duplicates, but no missing values.
#
# + Country of Operator/Owner:
# + The count values = 7560
# + Unique values = 104
# + There are duplicates, but no missing values.
# + Since these are variables I am interested in investigating, I decided to look into this further. It is expected to have duplicates as far as country names. However, I found some typos.
# + I created a "Multinational" category. The inconsistency was addressed and the data frame was updated.
# + Addressed the inconsistencies = # unique values = 74
#
#
# + Operator/Owner:
# + The count values = 7560
# + unique values = 665
# + There are duplicates, but no missing values.
#
# + Users:
# + The count values = 7560
# + unique values = 17
# + There are duplicates, but no missing values.
# + Since these are variables I am interested in investigating, I decided to look into this further. It is expected to have duplicates as far as User names. However, I found some typos.
# + I created a "Multi Users" category. The inconsistency was addressed and the data frame was updated.
# + Addressed the inconsistencies = # unique values = 5
#
# + Purpose:
# + The count values = 7560
# +  unique values = 3
# + There are duplicates, but no missing values.
#
# + Detailed Purpose:
# + The count values = 1254
# +  unique values = 54
# + There are duplicates, but no missing values.
#
# + Class of Orbit:
# + The count values = 7560
# +  unique values = 5
# + There are duplicates, but no missing values.
# + Since these are variables I am interested in investigating, I decided to look into this further. It is expected to have duplicates as far as Class of Orbit names. However, I found some typos.
# + The inconsistency was addressed and the data frame was updated.
# + Addressed the inconsistencies = # unique values = 4
#
# + Type of Orbit:
# + The count values = 6909
# +  unique values = 11
# + There are duplicates, but no missing values.
#
# + Period (minutes):
# + The count values = 7504
# +  unique values = 578
# + There are duplicates, and there are missing values.
#
# + Launch Mass (kg.):
# + The count values = 1315
# +  unique values = 595
# + There are duplicates, and there are missing values.
#
# + Dry Mass (kg.):
# + The count values = 7560
# +  unique values = 205
# + There are duplicates, but no missing values.
#
# + Power (watts):
# + The count values = 7560
# +  unique values = 153
# + There are duplicates, but no missing values.
#
# + Date of Launch:
# + The count values = 7560
# +  unique values = 1225
# + There are duplicates, but no missing values.
#
# + Expected Lifetime (yrs.):
# + The count values = 5450
# +  unique values = 28
# + There are duplicates, but no missing values.
#
# + Contractor:
# + The count values = 7560
# +  unique values = 568
# + There are duplicates, but no missing values.
#
# + Country of Contractor:
# + The count values = 7560
# + unique values = 99
# + There are duplicates, but no missing values.
# + Since these are variables I am interested in investigating, I decided to look into this further. It is expected to have duplicates as far as country names. There are some typos.
# + I created a "Multinational" category. The inconsistency was addressed, and the data frame was updated.
# + Addressed the inconsistencies = # unique values = 58
#
# + Launch Site:
# + The count values = 7560
# +  unique values = 40
# + There are duplicates, but no missing values.
#
# + Launch Vehicle:
# + The count values = 7560
# +  unique values = 163
# + There are duplicates, but no missing values.
#
# + Date of Launch:
# + The count values = 7560
# +  unique values = 1225
# + There are duplicates, but no missing values.
# + Since these are variables I am interested in investigating, I decided to look into this further. It is expected to have duplicates as far as country names. There are some typos.
# + The inconsistency was addressed, and the data frame was updated.
# + Addressed the inconsistencies = # unique values = 1225
#
# ## The dataset contains —df_dropped_3— 7560 rows and 19 columns
#
# ## Duplicate Checks
#
# + There are duplicates in the data.
# + There are a total of 8 exact duplicate rows in the data frame. I created a new DataFrame containing only the duplicate rows.
# + I dropped the 8 duplicates from the data frame and assigned it to a new data frame.
#
# ## The dataset contains —df_dropped_3_no_dups— 7552 rows and 19 columns.
#
# ## Missing Data
#
# + There are missing values in the data.
# + Period (minutes): missing values = 56
# + Launch Mass (kg.): = 245
# + Expected Lifetime (yrs.): = 2110
#
# + Addressing the missing values in the variables I am interested in per the proposed questions.
# + I created a subset of the dataframe, `df_nan`, that only contains rows with missing values.
# + The —Satellite ID 2023-041C has many missing values; therefore, I decided to drop it.
# + The dataset contains —df_dropped_2— 7551 rows and 19 columns.
#
# + Launch Mass (kg.):
# + Checked the missing values in the 'Launch Mass (kg.)' based on Class of Orbit.
# + I decided to replace the missing values of the Launch Mass based on Class of Orbit.
# + Missing values of the Launch Mass were replaced based on Class of Orbit.
# + Elliptical = 7 missing values
# + GEO = 36 missing values
# + LEO = 200 missing values
# + MEO = 1 missing values
#
#
# + I took the average Launch Mass for each class and replaced the Launch Mass values based on that.
# + Elliptical: replaced with the average value = 1898
# + GEO: replaced with the average value = 4083
# + LEO: replaced with the average value = 311
# + MEO: replaced with the average value = 1250
# + Filled the NaN values of the "Launch Mass" within the "Elliptical" Orbit and assigned it to a new dataframe.
# + Filled the NaN values of the "Launch Mass" within the "GEO" Orbit and updated the dataframe.
# + Filled the NaN values of the "Launch Mass" within the "LEO" Orbit and updated the dataframe.
# + Filled the NaN values of the "Launch Mass" within the "MEO" Orbit and updated the dataframe.
#
# + Expected Lifetime (yrs.):
# + Checked the missing values in the 'Expected Lifetime (yrs.)' based on Class of Orbit.
# + I decided to replace the missing values of the Expected Lifetime (yrs.) based on Class of Orbit.
# + I took the average Expected Lifetime (yrs.) for each class and replaced the Expected Lifetime (yrs.) values based on that.
# + Elliptical: replaced with he average values = 6
# + GEO: replaced with he average values = 13
# + LEO: replaced with he average values = 4
# + MEO:  replaced with he average values = 9
#
# + Filled the NaN values of the "Expected Lifetime" within the "Elliptical" Orbit and updated the dataframe.
# + Filled the NaN values of the "Expected Lifetime" within the "GEO" Orbit and updated the dataframe.
# + Filled the NaN values of the "Expected Lifetime" within the "LEO" Orbit and updated the dataframe.
# + Filled the NaN values of the "Expected Lifetime" within the "MEO" Orbit and updated the dataframe.
#
# + Period (minutes):
# + I checked the missing values in the Period (minutes) based on Class of Orbit.
# + I decided to replace the missing values of the Period (minutes) based on Class of Orbit.
# + I took the average Period (minutes) for each class and replaced the Period (minutes) values based on that. The missing values are only where the Class of Orbit is GEO and LEO.
# + GEO: replaced with the average value = 1437
# + LEO: replaced with he average value = 96
#
#
# ## The dataset contains —df_dropped_3_no_dups— 7551 rows and 19 columns
#
#
# ### Address the Time Date variable
# + There are typos and incorrect formatting values.
# + The formatting was addressed using Excel.
# + In Excel - I changed the column formate to Text via “Text to Column”
# + The inconsistency was addressed.
#
# Address the Time Date variable.
# + There are typos and incorrect formatting values.
# + The formatting was addressed using Excel.
# + In Excel, I changed the column format to Text using the "Text to Columns" feature.
# + The inconsistency was addressed.
# + Updated: # of unique values = 1224
#
# + I converted the column "Date of Launch" to a datetime type.
# + I separated the "Date of Launch" into year, month, and day components (time components were removed using Excel).
#
# ## The dataset contains —df_dropped_2_no_dups— 7551 rows and 22 columns
#
# + I created a list of columns to drop: ['Date of Launch', 'Launch Day'].
# + I dropped the columns in the list from the dataframe and assigned it to a new dataframe.
#
# ## The dataset contains —df_clean— 7551 rows and 20 columns
#
# ## Summary Statistics¶
# + All the quantitative variables are within an acceptable range.
# + Qualitative variables are noted.
#
#
# ### A list of dataframes
# + df
# + df_dropp
# + df_dropped_2
# + df_dropped_2_reorder
# + df_datatype
# + df_dropped_3
# + df_dropped_3_dups
# + df_dropped_3_no_dups
# + df_nan
# + df_clean
